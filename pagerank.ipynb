# %%
# !pip install fast-pagerank numpy scipy pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fast-pagerank in /Users/hieuhatrung/Library/Python/3.9/lib/python/site-packages (1.0.0)
# Requirement already satisfied: numpy in /Users/hieuhatrung/Library/Python/3.9/lib/python/site-packages (2.0.2)
# Requirement already satisfied: scipy in /Users/hieuhatrung/Library/Python/3.9/lib/python/site-packages (1.13.1)
# Requirement already satisfied: pymongo in /Users/hieuhatrung/Library/Python/3.9/lib/python/site-packages (4.11.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/hieuhatrung/Library/Python/3.9/lib/python/site-packages (from pymongo) (2.7.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client["cdp_database"]
tweets_col = db["tweets"]
users_col = db["twitter_raw"]

kol_usernames = users_col.distinct("userName", {"elite": True})
start_time = 1731628800
end_time = 1734220800
filters = {
    "timestamp": {"$gte": start_time, "$lte": end_time},
    "authorName": {"$in": kol_usernames}
}


pipeline = [
    {"$match": filters},
    {"$group": {
        "_id": "$authorName",
        "tweet_count": {"$sum": 1}
    }},
    {"$group": {
        "_id": None,
        "unique_authors": {"$sum": 1},
        "total_tweets": {"$sum": "$tweet_count"}
    }}
]


result = list(tweets_col.aggregate(pipeline))
if result:
    total_users = result[0]["unique_authors"]
    total_tweets = result[0]["total_tweets"]
    print(f"Total users: {total_users}, Total tweets: {total_tweets}")
else:
    print("No data found.")
# Out:
# Total users: 19992, Total tweets: 1515138

# %%
count_i = 0
for i in kol_usernames:
    count_i += 1
print(count_i)
# Out:
# 20210

# %%
data = {user: {"username": user, "mentioned": 0, "retweeted": 0} for user in kol_usernames}
print(data)
# Out:
# {'000__no': {'username': '000__no', 'mentioned': 0, 'retweeted': 0}, '008Nate': {'username': '008Nate', 'mentioned': 0, 'retweeted': 0}, '00scuba415': {'username': '00scuba415', 'mentioned': 0, 'retweeted': 0}, '00xJUAN': {'username': '00xJUAN', 'mentioned': 0, 'retweeted': 0}, '011101108a': {'username': '011101108a', 'mentioned': 0, 'retweeted': 0}, '0112358Stitch': {'username': '0112358Stitch', 'mentioned': 0, 'retweeted': 0}, '01573bit': {'username': '01573bit', 'mentioned': 0, 'retweeted': 0}, '06674eth': {'username': '06674eth', 'mentioned': 0, 'retweeted': 0}, '070guy': {'username': '070guy', 'mentioned': 0, 'retweeted': 0}, '089Reggie089': {'username': '089Reggie089', 'mentioned': 0, 'retweeted': 0}, '0913_marco': {'username': '0913_marco', 'mentioned': 0, 'retweeted': 0}, '0EllxJay': {'username': '0EllxJay', 'mentioned': 0, 'retweeted': 0}, '0FJAKE': {'username': '0FJAKE', 'mentioned': 0, 'retweeted': 0}, '0GAntD': {'username': '0GAntD', 'mentioned': 0, 'retweeted': 0}, '0XAKYLLES': {'username': '0XAKYLLES', 'mentioned': 0, 'retweeted': 0}, '0X_liquidate': {'username': '0X_liquidate', 'mentioned': 0, 'retweeted': 0}, '0_weimar2': {'username': '0_weimar2', 'mentioned': 0, 'retweeted': 0}, '0definitely0': {'username': '0definitely0', 'mentioned': 0, 'retweeted': 0}, '0domart': {'username': '0domart', 'mentioned': 0, 'retweeted': 0}, '0fficialmaddawg': {'username': '0fficialmaddawg', 'mentioned': 0, 'retweeted': 0}, '0gzombie': {'username': '0gzombie', 'mentioned': 0, 'retweeted': 0}, '0htli': {'username': '0htli', 'mentioned': 0, 'retweeted': 0}, '0itsali0': {'username': '0itsali0', 'mentioned': 0, 'retweeted': 0}, '0kyblake': {'username': '0kyblake', 'mentioned': 0, 'retweeted': 0}, '0ldgravy': {'username': '0ldgravy', 'mentioned': 0, 'retweeted': 0}, '0lliecrypto': {'username': '0lliecrypto', 'mentioned': 0, 'retweeted': 0}, '0pseudonym0': {'username': '0pseudonym0', 'mentioned': 0, 'retweeted': 0}, '0rdlibrary': {'username': '0rdlibrary', 'mentioned': 0, 'retweeted': 0}, '0x0000G': {'username': '0x0000G', 'mentioned': 0, 'retweeted': 0}, '0x002timmy': {'username': '0x002timmy', 'mentioned': 0, 'retweeted': 0}, '0x01yuqi': {'username': '0x01yuqi', 'mentioned': 0, 'retweeted': 0}, '0x0b0e': {'username': '0x0b0e', 'mentioned': 0, 'retweeted': 0}, '0x0lm': {'username': '0x0lm', 'mentioned': 0, 'retweeted': 0}, '0x0xFeng': {'username': '0x0xFeng', 'mentioned': 0, 'retweeted': 0}, '0x113d': {'username': '0x113d', 'mentioned': 0, 'retweeted': 0}, '0x1Oreo': {'username': '0x1Oreo', 'mentioned': 0, 'retweeted': 0}, '0x1dad': {'username': '0x1dad', 'mentioned': 0, 'retweeted': 0}, '0x1ee7': {'username': '0x1ee7', 'mentioned': 0, 'retweeted': 0}, '0x1x3x': {'username': '0x1x3x', 'mentioned': 0, 'retweeted': 0}, '0x3van': {'username': '0x3van', 'mentioned': 0, 'retweeted': 0}, '0x3y3': {'username': '0x3y3', 'mentioned': 0, 'retweeted': 0}, '0x4008': {'username': '0x4008', 'mentioned': 0, 'retweeted': 0}, '0x404page': {'username': '0x404page', 'mentioned': 0, 'retweeted': 0}, '0x4321': {'username': '0x4321', 'mentioned': 0, 'retweeted': 0}, '0x542121': {'username': '0x542121', 'mentioned': 0, 'retweeted': 0}, '0x5f_eth': {'username': '0x5f_eth', 'mentioned': 0, 'retweeted': 0}, '0x6851': {'username': '0x6851', 'mentioned': 0, 'retweeted': 0}, '0x69b9': {'username': '0x69b9', 'mentioned': 0, 'retweeted': 0}, '0x6Paths': {'username': '0x6Paths', 'mentioned': 0, 'retweeted': 0}, '0x7ama': {'username': '0x7ama', 'mentioned': 0, 'retweeted': 0}, '0x7d54': {'username': '0x7d54', 'mentioned': 0, 'retweeted': 0}, '0x8BitArt': {'username': '0x8BitArt', 'mentioned': 0, 'retweeted': 0}, '0x8i11i0n': {'username': '0x8i11i0n', 'mentioned': 0, 'retweeted': 0}, '0x99Gohan': {'username': '0x99Gohan', 'mentioned': 0, 'retweeted': 0}, '0x9clover': {'username': '0x9clover', 'mentioned': 0, 'retweeted': 0}, '0xAA_Science': {'username': '0xAA_Science', 'mentioned': 0, 'retweeted': 0}, '0xABRO': {'username': '0xABRO', 'mentioned': 0, 'retweeted': 0}, ' ...

# %%
filter_ = {
    "timestamp": {"$gte": start_time, "$lte": end_time},
    "authorName": {"$in": kol_usernames},
    "$or": [
        { "userMentions": { "$exists": True } },
        { "retweetedTweet": { "$exists": True } },
        {
            "$and": [
                { "userMentions": { "$exists": True } },
                { "retweetedTweet": { "$exists": True } }
            ]
        }
    ]
}
projection = {
    "authorName": 1,
    "userMentions": 1,
    "retweetedTweet": 1,
    "quotedTweet": 1
}
nodes = kol_usernames
edges = []
weights = []
post = 0
quote = 0
mention = 0
for tweet in tweets_col.find(filter_, projection=projection):
    author_name = tweet["authorName"]
    if "retweetedTweet" in tweet:
        original_author = tweet["retweetedTweet"]["authorName"]
        if author_name != original_author and original_author in kol_usernames:
            data[original_author]["retweeted"] += 1
            edges.append((author_name, original_author))
            weights.append(1)
            post += 1

    if "quotedTweet" in tweet:
        original_author = tweet["quotedTweet"]["authorName"]
        if author_name != original_author and original_author in kol_usernames:
            data[original_author]["retweeted"] += 1
            edges.append((author_name, original_author))
            weights.append(0.8)
            quote += 1

    if "userMentions" in tweet:
        for _id, username in tweet["userMentions"].items():
            if author_name != username and username in kol_usernames:
                data[username]["mentioned"] += 1
                edges.append((author_name, username))
                weights.append(0.6)
                mention += 1

print(f"Post: {post}, Quote: {quote}, Mention: {mention}")
# Out:
# Post: 200943, Quote: 35637, Mention: 352419

# %%
tweets_col.count_documents({
    "timestamp": {"$gte": start_time, "$lte": end_time},
    "authorName": {"$in": kol_usernames},
    "quotedTweet": { "$exists": True }
})
# Out:
# 335239

# %%
new_data = {}
for k, v in data.items():
    new_data[k] = v["mentioned"] + v["retweeted"]

# %%
bins = [0, 10, 20, 40, 60, 80, 100, 200, 300, 400, 500, 1000, 20000]
bin_labels = [f"({bins[i]}-{bins[i+1]}]" for i in range(len(bins) - 1)]

counts = {label: 0 for label in bin_labels}
for username, value in new_data.items():
    for i in range(len(bins) - 1):
        if bins[i] < value <= bins[i + 1]:
            counts[bin_labels[i]] += 1
            break

for bin_range, count in counts.items():
    print(f"{bin_range}: {count}")
# Out:
# (0-10]: 7125
# (10-20]: 2744
# (20-40]: 2478
# (40-60]: 1213
# (60-80]: 684
# (80-100]: 432
# (100-200]: 860
# (200-300]: 194
# (300-400]: 103
# (400-500]: 42
# (500-1000]: 50
# (1000-20000]: 23

# %%
import matplotlib.pyplot as plt

# Your processed data
counts = {
    "(0-10]": 7125,
    "(10-20]": 2744,
    "(20-40]": 2478,
    "(40-60]": 1213,
    "(60-80]": 684,
    "(80-100]": 432,
    "(100-200]": 860,
    "(200-300]": 194,
    "(300-400]": 103,
    "(400-500]": 42,
    "(500-1000]": 50,
    "(1000-20000]": 23
}

# Convert to lists for plotting
bins = list(counts.keys())
values = list(counts.values())

# Create a simple figure
plt.figure(figsize=(10, 6))

# Create a basic bar chart
plt.bar(bins, values, color='skyblue')

# Add simple labels
plt.xlabel('Mention and Retweet Frequency Ranges')
plt.ylabel('Number of Users')
plt.title('Distribution of Mentions and Retweets')

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right')

# Ensure layout fits well
plt.tight_layout()

# Save the figure
plt.savefig('mention_retweet_distribution.png')

# %%
import matplotlib.pyplot as plt

bins = list(counts.keys())
values = list(counts.values())

plt.figure(figsize=(12, 6))
plt.bar(bins, values, color='skyblue')

for i, value in enumerate(values):
    plt.text(i, value + max(values) * 0.01, str(value), ha='center', fontsize=10)

plt.xlabel('Edges', fontsize=12)
plt.ylabel('Nodes', fontsize=12)
plt.title('Exploratory Data Analysis', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
print(len(nodes), len(edges))
# Out:
# 20210 588999

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Create a graph
G = nx.DiGraph()

# Add all nodes first
for node in nodes:
    G.add_node(node)

# Add all edges with their weights
for (source, target), weight in zip(edges, weights):
    G.add_edge(source, target, weight=weight)

# Create visualization
plt.figure(figsize=(20, 20))

# Use a force-directed layout
pos = nx.spring_layout(G, k=1/np.sqrt(len(G)), iterations=50)

# Calculate node sizes based on degree centrality
degree_dict = dict(G.degree())
node_sizes = [v * 2 for v in degree_dict.values()]

# Draw the network
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, alpha=0.6, node_color='skyblue')
nx.draw_networkx_edges(G, pos, alpha=0.1, arrows=False)  # Set alpha low for better visibility with many edges

plt.title(f"KOL Network\n{len(nodes)} nodes, {len(edges)} edges", pad=20)
plt.axis('off')

# Save with high resolution
plt.savefig('kol_network_full.png', dpi=300, bbox_inches='tight')
plt.close()

print(f"Network visualization saved as 'kol_network_full.png'")
print(f"Network statistics:")
print(f"Number of nodes: {len(G.nodes())}")
print(f"Number of edges: {len(G.edges())}")
print(f"Network density: {nx.density(G):.6f}")
print(f"Average degree: {sum(dict(G.degree()).values())/len(G):.2f}")

# Calculate and display top 10 nodes by degree
top_degrees = sorted(degree_dict.items(), key=lambda x: x[1], reverse=True)[:10]
print("\nTop 10 nodes by degree:")
for node, degree in top_degrees:
    print(f"{node}: {degree} connections")
# Out:
# Network visualization saved as 'kol_network_full.png'
# Network statistics:
# Number of nodes: 20210
# Number of edges: 201101
# Network density: 0.000492
# Average degree: 19.90
#
# Top 10 nodes by degree:
# aixbt_agent: 1452 connections
# blknoiz06: 997 connections
# DegenerateNews: 787 connections
# saylor: 734 connections
# MustStopMurad: 731 connections
# cz_binance: 718 connections
# waleswoosh: 635 connections
# jessepollak: 633 connections
# LucaNetz: 620 connections
# brian_armstrong: 591 connections

# %%
from scipy import sparse
from fast_pagerank import pagerank
from fast_pagerank import pagerank_power
import numpy as np

num_nodes = len(nodes)

node_to_index = {node: index for index, node in enumerate(nodes)}

edges_indices = [(node_to_index[u], node_to_index[v]) for u, v in edges]


A = np.array(edges_indices)
G = sparse.csr_matrix((weights, (A[:, 0], A[:, 1])), shape=(num_nodes, num_nodes))

print("Tính PageRank")
damping_factor = 0.85
pagerank_scores = pagerank(G, p=damping_factor)
# Out:
# Tính PageRank

# %%
pagerank_scores
# Out:
# array([1.75449571e-05, 5.78929984e-05, 9.06709123e-06, ...,
#        9.06709123e-06, 9.49529449e-05, 1.00280675e-05])

# %%
import numpy as np

sorted_indices = np.argsort(pagerank_scores)[::-1]
sorted_scores = pagerank_scores[sorted_indices]
sorted_nodes = [nodes[i] for i in sorted_indices]


scaled_scores = sorted_scores * 10000

rank = 0
results = {}
for i, (username, score) in enumerate(zip(sorted_nodes, scaled_scores)):
    rank += 1
    # if rank > 10:
    #     break
    print(f"Hạng {i+1}: {username} - {score:.4f}")
    results[username] = score
# Out:
# Hạng 1: aixbt_agent - 81.4286
# Hạng 2: saylor - 74.3875
# Hạng 3: blknoiz06 - 44.7501
# Hạng 4: cz_binance - 43.6360
# Hạng 5: jessepollak - 34.5796
# Hạng 6: notthreadguy - 33.9554
# Hạng 7: brian_armstrong - 33.3316
# Hạng 8: CynthiaMLummis - 32.2249
# Hạng 9: truth_terminal - 30.6033
# Hạng 10: chooserich - 30.4212
# Hạng 11: pmarca - 27.5305
# Hạng 12: LeonidasNFT - 25.9375
# Hạng 13: 0xMert_ - 25.7376
# Hạng 14: EleanorTerrett - 25.5369
# Hạng 15: 0xzerebro - 24.1779
# Hạng 16: DegenerateNews - 24.1332
# Hạng 17: aeyakovenko - 22.9988
# Hạng 18: LucaNetz - 22.5743
# Hạng 19: AndyAyrey - 22.1054
# Hạng 20: MustStopMurad - 21.8614
# Hạng 21: Dennis_Porter_ - 21.6804
# Hạng 22: shawmakesmagic - 21.2857
# Hạng 23: beeple - 20.9978
# Hạng 24: FinancialCmte - 20.6903
# Hạng 25: frankdegods - 20.6339
# Hạng 26: justinsuntron - 20.3502
# Hạng 27: dolos_diary - 19.1142
# Hạng 28: JSeyff - 18.9527
# Hạng 29: waleswoosh - 18.8593
# Hạng 30: leap_xyz - 18.8520
# Hạng 31: iampaulgrewal - 18.8043
# Hạng 32: CozomoMedici - 18.3408
# Hạng 33: EricBalchunas - 17.7548
# Hạng 34: APompliano - 17.3077
# Hạng 35: inversebrah - 17.1892
# Hạng 36: SolJakey - 16.8333
# Hạng 37: piovincenzo_ - 16.6936
# Hạng 38: AltcoinDailyio - 16.4339
# Hạng 39: natbrunell - 16.0254
# Hạng 40: AutismCapital - 15.1794
# Hạng 41: naval - 15.1166
# Hạng 42: itsafwog - 15.0750
# Hạng 43: jerallaire - 14.8728
# Hạng 44: CharlotteFang77 - 14.8622
# Hạng 45: ThinkingUSD - 14.7590
# Hạng 46: GeezOnApe - 14.5174
# Hạng 47: based16z - 14.1970
# Hạng 48: fundstrat - 13.5662
# Hạng 49: CryptoGarga - 13.4861
# Hạng 50: BTC_Archive - 13.3801
# Hạng 51: ZssBecker - 13.1093
# Hạng 52: weremeow - 13.1030
# Hạng 53: CathieDWood - 13.0793
# Hạng 54: JakeGagain - 12.9627
# Hạng 55: SHL0MS - 12.7963
# Hạng 56: trentdotsol - 12.4494
# Hạng 57: ARKInvest - 12.2925
# Hạng 58: Chilearmy123 - 11.8959
# Hạng 59: RektCoin - 11.2990
# Hạng 60: USRepMikeFlood - 11.2198
# Hạng 61: PunterJeff - 11.1938
# Hạng 62: IOHK_Charles - 11.1727
# Hạng 63: bryanbrinkman - 11.0473
# Hạng 64: Jihoz_Axie - 10.9319
# Hạng 65: farokh - 10.6007
# Hạng 66: iamDCinvestor - 10.5093
# Hạng 67: tyler - 10.4536
# Hạng 68: blockspacepod - 10.2511
# Hạng 69: Scaramucci - 10.1374
# Hạng 70: bgarlinghouse - 10.1348
# Hạng 71: chillguycto - 9.6118
# Hạng 72: jon_charb - 9.5864
# Hạng 73: barkmeta - 9.5687
# Hạng 74: HHorsley - 9.5305
# Hạng 75: fgthiel - 9.4218
# Hạng 76: EasyEatsBodega - 9.3539
# Hạng 77: ICOffenderII - 9.2642
# Hạng 78: osf_rekt - 9.2524
# Hạng 79: BlockchainAssn - 9.1796
# Hạng 80: rasmr_eth - 9.0451
# Hạng 81: vaneck_us - 9.0264
# Hạng 82: Groowut - 8.9799
# Hạng 83: UNFKearth - 8.9207
# Hạng 84: RaoulGMI - 8.8767
# Hạng 85: DeeZe - 8.8463
# Hạng 86: 0xCygaar - 8.6621
# Hạng 87: KMSmithDC - 8.6053
# Hạng 88: RogerDickerman - 8.5628
# Hạng 89: keoneHD - 8.5197
# Hạng 90: boldleonidas - 8.5170
# Hạng 91: Zagabond - 8.4475
# Hạng 92: cameron - 8.1311
# Hạng 93: MaxResnick1 - 8.1063
# Hạng 94: backseats_eth - 7.8571
# Hạng 95: shiro - 7.8500
# Hạng 96: RidazLp2 - 7.7613
# Hạng 97: js_horne - 7.6246
# Hạng 98: GwartyGwart - 7.6075
# Hạng 99: MINHxDYNASTY - 7.5736
# Hạng 100: TO - 7.5231
# Hạng 101: GodsBurnt - 7.5061
# Hạng 102: IncomeSharks - 7.4245
# Hạng 103: kris - 7.4026
# Hạng 104: BitcoinNewsCom - 7.3391
# Hạng 105: Pizza_Ninjas - 7.3271
# Hạng 106: RadarHits - 7.3246
# Hạng 107: rektmando - 7.3166
# Hạng 108: yellowpantherx - 7.2958
# Hạng 109: BillyM2k - 7.2778
# Hạng 110: _RichardTeng - 7.2322
# Hạng 111: rushimanche - 7.1685
# Hạng 112: pnutsolana - 7.1641
# Hạng 113: jyu_eth - 7.1632
# Hạng 114: gainzy222 - 7.1543
# Hạng 115: hasbulla_main - 7.1199
# Hạng 116: intangiblecoins - 7.0839
# Hạng 117: econoar - 7.0677
# Hạng 118: DavidFBailey - 7.0602
# Hạng 119: blocknewsdotcom - 7.0567
# Hạng 120: TheFlowHorse - 6.9464
# Hạng 121: kikanicolela - 6.8591
# Hạng 122: himgajria - 6.8159
# Hạng 123: dankrad - 6.7837
# Hạng 124: artsch00lreject - 6.7584
# Hạng 125: wizardofsoho - 6.7416
# Hạng 126: OhYouBlockhead - 6.7047
# Hạng 127: solanasteve_ - 6.7009
# Hạng 128: mattmedved - 6.6905
# Hạng 129: ppmctweets - 6.6774
# Hạng 130: d_gilz - 6.5756
# Hạng 131: DSBatten - 6.4851
# Hạng 132: heyibinance - 6.4496
# Hạng 133: KookCapitalLLC - 6.3920
# Hạng 134: lBattleRhino - 6.3521
# Hạng 135: KevinWSHPod - 6.3333
# Hạng 136: TiffanyFong_ - 6.2626
# Hạng 137: naiivememe - 6.2533
# Hạng 138: NateGeraci - 6.1566
# Hạng 139: EmanAbio - 6.1456
# Hạng 140: kmoney_69 - 6.1373
# Hạng 141: Tradermayne - 6.1196
# Hạng 142: Matt_Hougan - 6.1084
# Hạng 143: dgt10011 - 6.0881
# Hạng 144: BoredApeSolClub - 6.0765
# Hạng 145: kukulabanze - 6.0613
# Hạng 146: delta_sauce - 6.0482
# Hạng 147: MacroCRG - 6.0333
# Hạng 148: 0xAneri - 6.0055
# Hạng 149: rajgokal - 5.9932
# Hạng 150: CryptoWizardd - 5.9220
# Hạng 151: digitalartchick - 5.9197
# Hạng 152: IsaacMiller - 5.8261
# Hạng 153: cburniske - 5.8239
# Hạng 154: Vince_Van_Dough - 5.7933
# Hạng 155: michaelmicasso - 5.7857
# Hạng 156: RealKatoOG - 5.7490
# Hạng 157: cryptolution101 - 5.7346
# Hạng 158: dak_daze - 5.7275
# Hạng 159: seedphrase - 5.7187
# Hạng 160: ericnode - 5.7025
# Hạng 161: lerandomart - 5.6920
# Hạng 162: _Shadow36 - 5.6687
# Hạng 163: AlexanderGrieve - 5.6657
# Hạng 164: BenArmstrongsX - 5.6545
# Hạng 165: coinbureau - 5.6048
# Hạng 166: Tyler_Did_It - 5.5994
# Hạng 167: punk9059 - 5.5970
# Hạng 168: LukeGromen - 5.5768
# Hạng 169: OneAndOnlyPapii - 5.5755
# Hạng 170: walletbubbles - 5.5275
# Hạng 171: theMiningPod - 5.4901
# Hạng 172: sassal0x - 5.4817
# Hạng 173: cryptojourneyrs - 5.4753
# Hạng 174: dotkrueger - 5.4631
# Hạng 175: DipWheeler - 5.4352
# Hạng 176: GOPMajorityWhip - 5.4228
# Hạng 177: sreeramkannan - 5.4186
# Hạng 178: TrustlessState - 5.3901
# Hạng 179: SpaceRidersXYZ - 5.3706
# Hạng 180: gammichan - 5.3682
# Hạng 181: SatoshiFlipper - 5.3667
# Hạng 182: bagdelete - 5.3427
# Hạng 183: MaxBecauseBTC - 5.3233
# Hạng 184: marka_eth - 5.3179
# Hạng 185: Austin_Federa - 5.3009
# Hạng 186: ChartFuMonkey - 5.2964
# Hạng 187: henokcrypto - 5.2819
# Hạng 188: gakonst - 5.2783
# Hạng 189: lex_node - 5.2700
# Hạng 190: LongLostNFT - 5.2614
# Hạng 191: justinaversano - 5.2551
# Hạng 192: FabianoSolana - 5.2548
# Hạng 193: zachxbt - 5.2379
# Hạng 194: aventurine_eth - 5.2366
# Hạng 195: batzdu - 5.2311
# Hạng 196: imperooterxbt - 5.2191
# Hạng 197: MariaShen - 5.2006
# Hạng 198: udiWertheimer - 5.1877
# Hạng 199: TaikiMaeda2 - 5.1403
# Hạng 200: NewsyJohnson - 5.1310
# Hạng 201: laurashin - 5.1297
# Hạng 202: fejau_inc - 5.1210
# Hạng 203: cmsholdings - 5.0526
# Hạng 204: Xeer - 5.0194
# Hạng 205: CaitlinLong_ - 5.0106
# Hạng 206: IHayato - 4.9931
# Hạng 207: CryptoKaleo - 4.9747
# Hạng 208: TheeHustleHouse - 4.9486
# Hạng 209: kelxyz_ - 4.9287
# Hạng 210: Bluntz_Capital - 4.9075
# Hạng 211: RyanWatkins_ - 4.8756
# Hạng 212: MrMigglesOnBase - 4.8637
# Hạng 213: elliotrades - 4.8448
# Hạng 214: JoeyMooose - 4.8316
# Hạng 215: cdixon - 4.8293
# Hạng 216: dabit3 - 4.7623
# Hạng 217: Coldie - 4.7586
# Hạng 218: solanapoet - 4.7395
# Hạng 219: GIGACHAD_meme - 4.7291
# Hạng 220: gianinaskarlett - 4.7243
# Hạng 221: muzzyvermillion - 4.7240
# Hạng 222: ZironiVioletta - 4.6844
# Hạng 223: TheOG_General - 4.6828
# Hạng 224: Pentosh1 - 4.6826
# Hạng 225: gee_otaryo - 4.6549
# Hạng 226: lepuppeteerfou - 4.6459
# Hạng 227: Ai420a12 - 4.6303
# Hạng 228: enjoyoor - 4.6168
# Hạng 229: redbeardnft - 4.5840
# Hạng 230: sunnymaanz - 4.5776
# Hạng 231: iceyyy_gaming - 4.5721
# Hạng 232: ArtOnBlockchain - 4.5654
# Hạng 233: CaballeroAnaMa - 4.5227
# Hạng 234: dankvr - 4.5144
# Hạng 235: thetrocro - 4.5016
# Hạng 236: TFTC21 - 4.4862
# Hạng 237: Darrenlautf - 4.4841
# Hạng 238: ayyyeandy - 4.4353
# Hạng 239: watchking69 - 4.4333
# Hạng 240: artcrushgallery - 4.4221
# Hạng 241: Excellion - 4.4158
# Hạng 242: drakefjustin - 4.3839
# Hạng 243: Persona_Journey - 4.3827
# Hạng 244: milesjennings - 4.3708
# Hạng 245: SUPERBASEDD - 4.3706
# Hạng 246: gerovich - 4.3477
# Hạng 247: ropirito - 4.3454
# Hạng 248: 0xuberM - 4.3324
# Hạng 249: meta_alchemist - 4.3138
# Hạng 250: tarunchitra - 4.2602
# Hạng 251: CryptoDonAlt - 4.2578
# Hạng 252: scottshapiro - 4.2315
# Hạng 253: thegoodtimeline - 4.2244
# Hạng 254: BecauseBitcoin - 4.2237
# Hạng 255: DeFi_Dad - 4.2219
# Hạng 256: ARafayGadit - 4.2216
# Hạng 257: armaniferrante - 4.2191
# Hạng 258: billydollarcat - 4.2075
# Hạng 259: BTCsessions - 4.1930
# Hạng 260: avichal - 4.1758
# Hạng 261: burnttoast - 4.1670
# Hạng 262: CL207 - 4.1580
# Hạng 263: cryptopunk7213 - 4.1468
# Hạng 264: cyodyssey - 4.1435
# Hạng 265: MikeIppolito_ - 4.1062
# Hạng 266: re_generates - 4.1030
# Hạng 267: deepname99 - 4.0789
# Hạng 268: SamSteffanina - 4.0636
# Hạng 269: wallstreetbets - 4.0590
# Hạng 270: gmoneyNFT - 4.0348
# Hạng 271: JimenaBuenaVida - 4.0192
# Hạng 272: JasonYanowitz - 4.0162
# Hạng 273: petewnoble - 3.9976
# Hạng 274: dystopiabreaker - 3.9975
# Hạng 275: Minotaur_Man - 3.9836
# Hạng 276: beaniemaxi - 3.9750
# Hạng 277: Blondie23LMD - 3.9715
# Hạng 278: MetaVixensNFT - 3.9634
# Hạng 279: BillHughesDC - 3.9463
# Hạng 280: TheBTCTherapist - 3.9453
# Hạng 281: WegenNFT - 3.9224
# Hạng 282: SOLsesame - 3.9189
# Hạng 283: pushpendrakum - 3.8962
# Hạng 284: 0xMoon6626 - 3.8827
# Hạng 285: TeTheGamer - 3.8720
# Hạng 286: degenharambe - 3.8602
# Hạng 287: 9trevv - 3.8425
# Hạng 288: VittoPantoliano - 3.8227
# Hạng 289: MartyBent - 3.8219
# Hạng 290: zubic_eth - 3.8171
# Hạng 291: taylorjbarr - 3.7854
# Hạng 292: WalkerAmerica - 3.7799
# Hạng 293: RealDuckMaster - 3.7704
# Hạng 294: zacxbt - 3.7604
# Hạng 295: poof_eth - 3.7591
# Hạng 296: JiraiyaReal - 3.7380
# Hạng 297: leonabboud_ - 3.7363
# Hạng 298: hosseeb - 3.7347
# Hạng 299: pythianism - 3.7347
# Hạng 300: 0xThaDream - 3.7212
# Hạng 301: Lightspeedpodhq - 3.7191
# Hạng 302: emilyxxie - 3.7126
# Hạng 303: dxrnelljcl - 3.7033
# Hạng 304: moneyl0rd - 3.7017
# Hạng 305: legendarygainz_ - 3.6995
# Hạng 306: chainyoda - 3.6930
# Hạng 307: Berko_Crypto - 3.6746
# Hạng 308: ASvanevik - 3.6674
# Hạng 309: LeslieASpurlock - 3.6611
# Hạng 310: ChrisJourdan - 3.6598
# Hạng 311: maxkeiser - 3.6508
# Hạng 312: SteveMiller_PHX - 3.6403
# Hạng 313: CryptosR_Us - 3.6273
# Hạng 314: naniXBT - 3.6273
# Hạng 315: vydamo_ - 3.6092
# Hạng 316: beast_ico - 3.6090
# Hạng 317: Jeremyybtc - 3.5973
# Hạng 318: CoinBureauTr - 3.5872
# Hạng 319: amadon - 3.5744
# Hạng 320: SmallCapScience - 3.5738
# Hạng 321: raphael_erba - 3.5670
# Hạng 322: ShytoshiKusama - 3.5618
# Hạng 323: RonwHammond - 3.5562
# Hạng 324: MetaKozo - 3.5545
# Hạng 325: gregosuri - 3.5470
# Hạng 326: jed_131 - 3.5297
# Hạng 327: dwr - 3.5250
# Hạng 328: iamkadense - 3.5037
# Hạng 329: bull_bnb - 3.5029
# Hạng 330: templecrash - 3.4911
# Hạng 331: khouuba - 3.4721
# Hạng 332: etherstu - 3.4401
# Hạng 333: TraderKoz - 3.4389
# Hạng 334: TimBeiko - 3.4263
# Hạng 335: shanicucic96 - 3.4230
# Hạng 336: 1CrypticPoet - 3.4110
# Hạng 337: SpikePersona - 3.4093
# Hạng 338: Cooopahtroopa - 3.4079
# Hạng 339: jussy_world - 3.4051
# Hạng 340: Ashcryptoreal - 3.3995
# Hạng 341: 0xQuit - 3.3973
# Hạng 342: lopp - 3.3841
# Hạng 343: wiseadvicesumit - 3.3744
# Hạng 344: worldofwhiteboy - 3.3720
# Hạng 345: soby0x - 3.3532
# Hạng 346: SCHIZO_FREQ - 3.3491
# Hạng 347: bitstein - 3.3460
# Hạng 348: rektech - 3.3278
# Hạng 349: huuep - 3.3247
# Hạng 350: Zeneca - 3.3240
# Hạng 351: el33th4xor - 3.3215
# Hạng 352: schmrypto - 3.3210
# Hạng 353: trevorjonesart - 3.3044
# Hạng 354: Vivek4real_ - 3.3029
# Hạng 355: Tma_420 - 3.3004
# Hạng 356: beausecurity - 3.2947
# Hạng 357: bunya_eth - 3.2908
# Hạng 358: chefgoyardi - 3.2782
# Hạng 359: CampbellJAustin - 3.2765
# Hạng 360: coffeebreak_YT - 3.2752
# Hạng 361: AshleyDCan - 3.2737
# Hạng 362: sgoldfed - 3.2736
# Hạng 363: icebergy_ - 3.2691
# Hạng 364: basileus_eth - 3.2656
# Hạng 365: hotpot_dao - 3.2593
# Hạng 366: 1000xgirl - 3.2585
# Hạng 367: buffalu__ - 3.2570
# Hạng 368: MycelialOracle - 3.2468
# Hạng 369: camolNFT - 3.2381
# Hạng 370: somewheresy - 3.2209
# Hạng 371: sovrnart - 3.2089
# Hạng 372: LionSnows - 3.2033
# Hạng 373: luigidemeo - 3.1938
# Hạng 374: carlabitcoin - 3.1874
# Hạng 375: jespow - 3.1829
# Hạng 376: Fiskantes - 3.1817
# Hạng 377: RyanSAdams - 3.1720
# Hạng 378: bigpeyYT - 3.1716
# Hạng 379: _ShaniceBest - 3.1713
# Hạng 380: jup_uplink - 3.1676
# Hạng 381: DianeDrubay - 3.1617
# Hạng 382: EfdotStudio - 3.1547
# Hạng 383: SalsaTekila - 3.1531
# Hạng 384: shadid_io - 3.1433
# Hạng 385: HypoNyms - 3.1431
# Hạng 386: kokid951 - 3.1398
# Hạng 387: GamingGridx - 3.1380
# Hạng 388: NONE32X32 - 3.1199
# Hạng 389: whyarethis - 3.1196
# Hạng 390: wintonARK - 3.1075
# Hạng 391: gomugator - 3.1073
# Hạng 392: ropAIrito - 3.1046
# Hạng 393: SmokeyTheBera - 3.1037
# Hạng 394: runetoshi21 - 3.0974
# Hạng 395: 0xBreadguy - 3.0896
# Hạng 396: cobyistheticker - 3.0892
# Hạng 397: MLeeJr - 3.0870
# Hạng 398: hkunimitsu - 3.0847
# Hạng 399: Real_Sugarverse - 3.0795
# Hạng 400: titcoinpodcast - 3.0757
# Hạng 401: adam3us - 3.0689
# Hạng 402: TimKotzman - 3.0684
# Hạng 403: hmalviya9 - 3.0644
# Hạng 404: Mr_WacCo - 3.0636
# Hạng 405: 0xLeoInRio - 3.0597
# Hạng 406: avedarave_ - 3.0568
# Hạng 407: 0xdiid - 3.0432
# Hạng 408: 0xRamonos - 3.0424
# Hạng 409: SuperRareRoses - 3.0359
# Hạng 410: KingAnt777 - 3.0192
# Hạng 411: postretardism - 3.0167
# Hạng 412: ArtverseParis - 3.0137
# Hạng 413: mendezmendezart - 3.0108
# Hạng 414: btcbongo - 3.0097
# Hạng 415: sershokunin - 3.0079
# Hạng 416: scottmelker - 3.0006
# Hạng 417: ciniz - 2.9917
# Hạng 418: eyezenhour - 2.9912
# Hạng 419: Pons_ETH - 2.9911
# Hạng 420: _gvan - 2.9804
# Hạng 421: pobedeen - 2.9646
# Hạng 422: notsofast - 2.9636
# Hạng 423: LilMoonLambo - 2.9631
# Hạng 424: JTLissPhotoArt - 2.9593
# Hạng 425: TheCryptoDog - 2.9587
# Hạng 426: erikaleetv - 2.9587
# Hạng 427: LexaproTrader - 2.9581
# Hạng 428: CryptoKaduna - 2.9561
# Hạng 429: TheDesertLynx - 2.9536
# Hạng 430: Web3MemeGuy - 2.9487
# Hạng 431: jasonjzhao - 2.9464
# Hạng 432: Arthur_0x - 2.9406
# Hạng 433: ExpandedArt - 2.9336
# Hạng 434: cagyjan1 - 2.9270
# Hạng 435: _jhunsaker - 2.9263
# Hạng 436: jakejfried - 2.9152
# Hạng 437: matthew_pines - 2.9145
# Hạng 438: RoundtableSpace - 2.9138
# Hạng 439: harto_fr - 2.9125
# Hạng 440: ruggedwithjack - 2.9113
# Hạng 441: ameensol - 2.9072
# Hạng 442: nonfungible_jan - 2.9064
# Hạng 443: veH0rny - 2.9031
# Hạng 444: akshaybd - 2.9023
# Hạng 445: Kellykellam - 2.8940
# Hạng 446: batsoupyum - 2.8933
# Hạng 447: rektdrinks - 2.8871
# Hạng 448: CryptoGuy_777 - 2.8857
# Hạng 449: solashenone - 2.8846
# Hạng 450: 0xKNL__ - 2.8730
# Hạng 451: maddox00000 - 2.8688
# Hạng 452: msoriaro - 2.8491
# Hạng 453: Glug69420 - 2.8483
# Hạng 454: wrld_sol - 2.8475
# Hạng 455: alliancedao - 2.8467
# Hạng 456: objktone - 2.8406
# Hạng 457: redphonecrypto - 2.8357
# Hạng 458: WolvesDAO - 2.8270
# Hạng 459: 0xSweep - 2.8251
# Hạng 460: BoDoggosENT - 2.8250
# Hạng 461: ApeCryptos - 2.8227
# Hạng 462: icebagz_ - 2.8183
# Hạng 463: TheBirbNest - 2.8140
# Hạng 464: JiffyPB_ - 2.8124
# Hạng 465: _patrickogrady - 2.8113
# Hạng 466: CryptoEmpressX - 2.7982
# Hạng 467: cryptunez - 2.7944
# Hạng 468: rcivNFT - 2.7890
# Hạng 469: pointline_ - 2.7874
# Hạng 470: safetyth1rd - 2.7841
# Hạng 471: DJTRAXNFT - 2.7838
# Hạng 472: jalil_eth - 2.7813
# Hạng 473: kostascrypto - 2.7786
# Hạng 474: P1AbyPIA - 2.7744
# Hạng 475: orangie - 2.7677
# Hạng 476: IIICapital - 2.7556
# Hạng 477: matthew_sigel - 2.7497
# Hạng 478: RothDC - 2.7492
# Hạng 479: Making_Coffee_ - 2.7460
# Hạng 480: crypto_bitlord7 - 2.7415
# Hạng 481: danielkoeth - 2.7366
# Hạng 482: BrynDavis - 2.7340
# Hạng 483: ApeConcierge - 2.7238
# Hạng 484: trading_axe - 2.7152
# Hạng 485: ksicrypto - 2.7106
# Hạng 486: biptapofficial - 2.6829
# Hạng 487: monkantony_tez - 2.6801
# Hạng 488: moludotsol - 2.6776
# Hạng 489: OGDfarmer - 2.6756
# Hạng 490: ethwhaledave - 2.6750
# Hạng 491: Grimezsz - 2.6702
# Hạng 492: genuinearticles - 2.6678
# Hạng 493: dogeofficialceo - 2.6663
# Hạng 494: s_alderoty - 2.6644
# Hạng 495: sashastiles - 2.6529
# Hạng 496: zenryoku_eth - 2.6392
# Hạng 497: shivst3r - 2.6365
# Hạng 498: FamousCloudzz - 2.6350
# Hạng 499: 3orovik - 2.6346
# Hạng 500: 0xBalloonLover - 2.6296
# Hạng 501: OriginalGoldCat - 2.6293
# Hạng 502: pranksy - 2.6278
# Hạng 503: koto9x - 2.6097
# Hạng 504: ChainLinkGod - 2.6095
# Hạng 505: solos_gallery - 2.6058
# Hạng 506: smileycapital - 2.6036
# Hạng 507: ClownVamp - 2.6020
# Hạng 508: haydenzadams - 2.6008
# Hạng 509: metaversejoji - 2.5977
# Hạng 510: Slickmeta - 2.5964
# Hạng 511: 0x_Osprey - 2.5936
# Hạng 512: RobinSeyr - 2.5888
# Hạng 513: TimpersHD - 2.5856
# Hạng 514: martechnetworks - 2.5842
# Hạng 515: pokornstar - 2.5841
# Hạng 516: benzion_b - 2.5769
# Hạng 517: LaurenceFuller - 2.5761
# Hạng 518: CoinDeskPodcast - 2.5711
# Hạng 519: knveth - 2.5711
# Hạng 520: cointradernik - 2.5698
# Hạng 521: stevewilldoit - 2.5660
# Hạng 522: Greekdx - 2.5611
# Hạng 523: cbspears - 2.5609
# Hạng 524: rleshner - 2.5608
# Hạng 525: KeyboardMonkey3 - 2.5598
# Hạng 526: whatslukedoing - 2.5572
# Hạng 527: CoinDeskjapan - 2.5542
# Hạng 528: theonlyposted - 2.5508
# Hạng 529: refikanadol - 2.5507
# Hạng 530: 0xfar - 2.5493
# Hạng 531: 0xxNathan - 2.5465
# Hạng 532: wolfgangeth - 2.5448
# Hạng 533: VaderResearch - 2.5439
# Hạng 534: DemAzuki - 2.5424
# Hạng 535: EliBenSasson - 2.5412
# Hạng 536: ParallelAiRev - 2.5406
# Hạng 537: swansonbenson0 - 2.5396
# Hạng 538: CapetainTrippy - 2.5342
# Hạng 539: makun47525347 - 2.5304
# Hạng 540: milesdeutscher - 2.5279
# Hạng 541: HanaPersona_ - 2.5222
# Hạng 542: _0_0_0_9_ - 2.5221
# Hạng 543: Noahbolanowski - 2.5147
# Hạng 544: intocryptoverse - 2.5127
# Hạng 545: AnnaLZubarev - 2.5108
# Hạng 546: 0xMagmar - 2.5101
# Hạng 547: baoskee - 2.5082
# Hạng 548: Rewkang - 2.5078
# Hạng 549: paoloardoino - 2.4915
# Hạng 550: Skelhorn - 2.4913
# Hạng 551: DjinntXBT - 2.4878
# Hạng 552: wbnns - 2.4866
# Hạng 553: Goonz_World - 2.4824
# Hạng 554: 2red - 2.4818
# Hạng 555: leptokurtic_ - 2.4816
# Hạng 556: Fapital3 - 2.4794
# Hạng 557: davidgokhshtein - 2.4765
# Hạng 558: JohnWRichKid - 2.4745
# Hạng 559: skarlywarly - 2.4684
# Hạng 560: JuujuGirl - 2.4677
# Hạng 561: ErikVoorhees - 2.4644
# Hạng 562: redacted_noah - 2.4642
# Hạng 563: stephensantoro_ - 2.4619
# Hạng 564: mfermigo - 2.4619
# Hạng 565: tezukaTez - 2.4459
# Hạng 566: Klutch_NFT - 2.4440
# Hạng 567: ThankYouX - 2.4338
# Hạng 568: Idedj - 2.4331
# Hạng 569: Wolf0x67 - 2.4327
# Hạng 570: jchervinsky - 2.4289
# Hạng 571: degenspartanai - 2.4234
# Hạng 572: KCMontero - 2.4199
# Hạng 573: benbybit - 2.4175
# Hạng 574: Duelbits - 2.4162
# Hạng 575: mrjasonchoi - 2.4141
# Hạng 576: SteveKBark - 2.4108
# Hạng 577: AltcoinSherpa - 2.4043
# Hạng 578: fascinated - 2.4037
# Hạng 579: emilyxlai - 2.4019
# Hạng 580: _ilmoi - 2.3992
# Hạng 581: I____felix____I - 2.3954
# Hạng 582: JBSDC - 2.3943
# Hạng 583: marccolcer - 2.3919
# Hạng 584: sherlock_hodles - 2.3906
# Hạng 585: krugermacro - 2.3891
# Hạng 586: YisusCryptos - 2.3831
# Hạng 587: Pledditor - 2.3811
# Hạng 588: thisjackkaido - 2.3810
# Hạng 589: cryptoterry - 2.3805
# Hạng 590: 21Bitfluencers - 2.3750
# Hạng 591: ripcache - 2.3650
# Hạng 592: mitchellfchan - 2.3636
# Hạng 593: monstermike_art - 2.3602
# Hạng 594: 0xDesigner - 2.3596
# Hạng 595: DylanLeClair_ - 2.3592
# Hạng 596: CoinsWeb3 - 2.3564
# Hạng 597: ActuallyAgents - 2.3538
# Hạng 598: gigagriff - 2.3489
# Hạng 599: thepropgallery - 2.3481
# Hạng 600: SOLBigBrain - 2.3479
# Hạng 601: ProTheDoge - 2.3463
# Hạng 602: fintechfrank - 2.3460
# Hạng 603: exlawyernft - 2.3419
# Hạng 604: krtvdept - 2.3384
# Hạng 605: SheaKetsdever - 2.3304
# Hạng 606: CryptoParadyme - 2.3273
# Hạng 607: raidenkrn - 2.3272
# Hạng 608: BigDickBull69 - 2.3270
# Hạng 609: artandvault - 2.3239
# Hạng 610: CryptoWendyO - 2.3225
# Hạng 611: kurorosage - 2.3216
# Hạng 612: wagmiAlexander - 2.3204
# Hạng 613: 0x113d - 2.3196
# Hạng 614: NeerajKA - 2.3185
# Hạng 615: joemccann - 2.3171
# Hạng 616: FKA787 - 2.3143
# Hạng 617: illaDaProducer - 2.3139
# Hạng 618: santiagoroel - 2.3038
# Hạng 619: Lysss302 - 2.2984
# Hạng 620: BinanceTR - 2.2971
# Hạng 621: resistancemoney - 2.2919
# Hạng 622: GratefulApe_eth - 2.2903
# Hạng 623: nft_oliii - 2.2882
# Hạng 624: sauciii__ - 2.2870
# Hạng 625: thefunnyguysNFT - 2.2855
# Hạng 626: wirelyss - 2.2854
# Hạng 627: 0xrwu - 2.2816
# Hạng 628: tylerxhobbs - 2.2809
# Hạng 629: Web3Quant - 2.2770
# Hạng 630: FellowshipAi - 2.2665
# Hạng 631: NFTwap - 2.2656
# Hạng 632: BasedMinis - 2.2626
# Hạng 633: EricCryptoman - 2.2619
# Hạng 634: takeasip11 - 2.2599
# Hạng 635: eeelistar - 2.2564
# Hạng 636: yangl1996 - 2.2543
# Hạng 637: jords - 2.2535
# Hạng 638: bailey_tattoo - 2.2519
# Hạng 639: stacyherbert - 2.2505
# Hạng 640: valkenburgh - 2.2483
# Hạng 641: EdanYago - 2.2423
# Hạng 642: DirtyRobotWorks - 2.2410
# Hạng 643: 0xBurnt - 2.2397
# Hạng 644: vohvohh - 2.2386
# Hạng 645: CryptoHayes - 2.2341
# Hạng 646: MattKaneArtist - 2.2277
# Hạng 647: SolNorsey - 2.2237
# Hạng 648: jivdontexist - 2.2211
# Hạng 649: cometcalls - 2.2202
# Hạng 650: theomakaseshow - 2.2148
# Hạng 651: b1ackd0g - 2.2117
# Hạng 652: tinochchan - 2.2117
# Hạng 653: wanderlustonape - 2.2116
# Hạng 654: MrGreenity - 2.2115
# Hạng 655: SixP_ - 2.2106
# Hạng 656: hanna_iwanuma33 - 2.2096
# Hạng 657: briangarrett - 2.2033
# Hạng 658: eli5_defi - 2.1987
# Hạng 659: BrandonLewisMMA - 2.1972
# Hạng 660: divine_economy - 2.1952
# Hạng 661: ParinHeidari - 2.1919
# Hạng 662: giancarloMKTS - 2.1914
# Hạng 663: BenTodar - 2.1901
# Hạng 664: brainletCTO - 2.1877
# Hạng 665: JohnEDeaton1 - 2.1866
# Hạng 666: dutchtide - 2.1852
# Hạng 667: Pankekkeku - 2.1794
# Hạng 668: domainbubbles - 2.1785
# Hạng 669: AbsurdArtApes - 2.1727
# Hạng 670: eliz883 - 2.1706
# Hạng 671: punk7635 - 2.1643
# Hạng 672: iJmillz - 2.1560
# Hạng 673: _weidai - 2.1553
# Hạng 674: virotechnics - 2.1547
# Hạng 675: theblondebroker - 2.1494
# Hạng 676: ray_noOnes - 2.1428
# Hạng 677: rovercrc - 2.1401
# Hạng 678: RasterlyRock - 2.1349
# Hạng 679: lovaniceth - 2.1342
# Hạng 680: SanjayWeb3 - 2.1329
# Hạng 681: 7316 - 2.1276
# Hạng 682: MichaelKdcl - 2.1248
# Hạng 683: basilda_a - 2.1217
# Hạng 684: modernmarket_ - 2.1211
# Hạng 685: louisdazy - 2.1197
# Hạng 686: RDToTheMoon - 2.1189
# Hạng 687: GordonGoner - 2.1171
# Hạng 688: ChrisF_0x - 2.1164
# Hạng 689: NFT1nsight - 2.1068
# Hạng 690: FoxyPenguinApe - 2.1067
# Hạng 691: ganbrood - 2.1052
# Hạng 692: fxnction - 2.1024
# Hạng 693: MarediaShehzan - 2.1014
# Hạng 694: MajidXBT - 2.0996
# Hạng 695: faryarshirzad - 2.0963
# Hạng 696: jonwu_ - 2.0942
# Hạng 697: SharkAnth0ny - 2.0908
# Hạng 698: swagt0shi - 2.0908
# Hạng 699: 0xbags - 2.0892
# Hạng 700: betty_nft - 2.0888
# Hạng 701: NaughtalieStone - 2.0887
# Hạng 702: wabdoteth - 2.0859
# Hạng 703: rekt_tekashi - 2.0842
# Hạng 704: yuyumannn - 2.0806
# Hạng 705: clairekart - 2.0797
# Hạng 706: BoredApeGazette - 2.0788
# Hạng 707: BCheque1 - 2.0783
# Hạng 708: reaIityobserver - 2.0781
# Hạng 709: coinmerge - 2.0779
# Hạng 710: SolanaSensei - 2.0776
# Hạng 711: crypto_birb - 2.0768
# Hạng 712: OG_crookedwest - 2.0766
# Hạng 713: TheMisterFrog - 2.0748
# Hạng 714: brian_trollz - 2.0731
# Hạng 715: Wolfy_XBT - 2.0724
# Hạng 716: ClassicsCrypto - 2.0720
# Hạng 717: alexjmingolla - 2.0643
# Hạng 718: DotComParker - 2.0632
# Hạng 719: EvanWeb3 - 2.0576
# Hạng 720: ooguri888 - 2.0498
# Hạng 721: Relentless_btc - 2.0473
# Hạng 722: sozuhaus - 2.0435
# Hạng 723: SGJohnsson - 2.0404
# Hạng 724: kdean - 2.0397
# Hạng 725: ilyakazakov - 2.0380
# Hạng 726: jasonmdesimone - 2.0353
# Hạng 727: dev_allo - 2.0340
# Hạng 728: Scooter0x - 2.0332
# Hạng 729: Nate_Rivers - 2.0275
# Hạng 730: wsfoxley - 2.0270
# Hạng 731: gremplin - 2.0269
# Hạng 732: thisisdjen - 2.0248
# Hạng 733: MayaPar25 - 2.0247
# Hạng 734: cozypront - 2.0221
# Hạng 735: otograf_jp - 2.0216
# Hạng 736: AndyRewNFT - 2.0214
# Hạng 737: cloudwhiteNFT - 2.0201
# Hạng 738: iampapito_eth - 2.0173
# Hạng 739: swen_sjn - 2.0127
# Hạng 740: tintsion - 2.0126
# Hạng 741: realizingerin - 2.0121
# Hạng 742: _smkotaro - 2.0119
# Hạng 743: afscott - 2.0118
# Hạng 744: neurocolor - 2.0062
# Hạng 745: mraltantutar - 2.0036
# Hạng 746: DzambhalaHODL - 1.9999
# Hạng 747: kirbxbt - 1.9941
# Hạng 748: random_freaks - 1.9935
# Hạng 749: GoingParabolic - 1.9932
# Hạng 750: krito_carde - 1.9932
# Hạng 751: ercwl - 1.9929
# Hạng 752: ghost_ppx - 1.9905
# Hạng 753: roobzey - 1.9900
# Hạng 754: sartoshi_rip - 1.9890
# Hạng 755: goodalexander - 1.9850
# Hạng 756: Sinsonx - 1.9826
# Hạng 757: ilblackdragon - 1.9818
# Hạng 758: hasufl - 1.9806
# Hạng 759: Ippy_World - 1.9805
# Hạng 760: ALCrego_ - 1.9790
# Hạng 761: TopoGigio_sol - 1.9767
# Hạng 762: GGhyzmo - 1.9757
# Hạng 763: lilybrodi - 1.9696
# Hạng 764: kryptobaby777 - 1.9694
# Hạng 765: NFTdavie - 1.9647
# Hạng 766: JakeBalchNFT - 1.9642
# Hạng 767: CryptoStatuette - 1.9634
# Hạng 768: eth_call - 1.9597
# Hạng 769: KinglouiEth - 1.9564
# Hạng 770: realtombibiyan - 1.9527
# Hạng 771: DropMiin - 1.9512
# Hạng 772: xicojam - 1.9511
# Hạng 773: Route2FI - 1.9496
# Hạng 774: docXBT - 1.9485
# Hạng 775: intern - 1.9483
# Hạng 776: ol1y_art - 1.9478
# Hạng 777: CirrusNFT - 1.9469
# Hạng 778: ZhuoxunYin - 1.9466
# Hạng 779: jon_winchell - 1.9460
# Hạng 780: sergitosergito - 1.9409
# Hạng 781: TylerDurden - 1.9398
# Hạng 782: punk9527 - 1.9375
# Hạng 783: maxpretends - 1.9317
# Hạng 784: mrpunkdoteth - 1.9288
# Hạng 785: Jeni_Pepen - 1.9248
# Hạng 786: pablorfraile - 1.9248
# Hạng 787: 0xGouL - 1.9248
# Hạng 788: NoncoDucks - 1.9230
# Hạng 789: Sanza - 1.9230
# Hạng 790: thebellcurvepod - 1.9219
# Hạng 791: deftony83 - 1.9211
# Hạng 792: NewsAsset - 1.9209
# Hạng 793: BobuBeanFarmer - 1.9191
# Hạng 794: Salawaki_3000 - 1.9190
# Hạng 795: Kyroh - 1.9177
# Hạng 796: 0xBigVee - 1.9156
# Hạng 797: dim8765 - 1.9123
# Hạng 798: K1d_Crypt0 - 1.9119
# Hạng 799: Gogolitus - 1.9100
# Hạng 800: OGshoots - 1.9100
# Hạng 801: hellmoneypod - 1.9099
# Hạng 802: Chazwesley99 - 1.9092
# Hạng 803: omgidrawedit - 1.9086
# Hạng 804: dead_y00ts - 1.9080
# Hạng 805: Old_Samster - 1.9074
# Hạng 806: WOMENverse101 - 1.9036
# Hạng 807: LynAldenContact - 1.9009
# Hạng 808: Hydraze420 - 1.9007
# Hạng 809: ajwarner90 - 1.9002
# Hạng 810: SereinScripts - 1.8983
# Hạng 811: owocki - 1.8976
# Hạng 812: llamaonthebrink - 1.8976
# Hạng 813: foster_protocol - 1.8950
# Hạng 814: ExpectedValue_ - 1.8941
# Hạng 815: 0xMrWzrd - 1.8941
# Hạng 816: michaelbouhanna - 1.8936
# Hạng 817: operator_______ - 1.8887
# Hạng 818: Jack55750 - 1.8883
# Hạng 819: mdudas - 1.8873
# Hạng 820: AtikoAE - 1.8865
# Hạng 821: saucebook - 1.8847
# Hạng 822: OX_DAO - 1.8831
# Hạng 823: midnightclvb - 1.8828
# Hạng 824: DTAPCAP - 1.8824
# Hạng 825: 0xMLow - 1.8807
# Hạng 826: TheCryptoBubble - 1.8807
# Hạng 827: WutalkWu - 1.8801
# Hạng 828: web3pingu - 1.8795
# Hạng 829: tomatuuu11 - 1.8790
# Hạng 830: BAYC1K - 1.8767
# Hạng 831: Credzilla - 1.8758
# Hạng 832: jeremybooth - 1.8722
# Hạng 833: BobLoukas - 1.8717
# Hạng 834: iCrazyTeddy - 1.8712
# Hạng 835: ValyaNarts - 1.8693
# Hạng 836: Aizcalibur - 1.8672
# Hạng 837: bubblegum_dee - 1.8666
# Hạng 838: Dragonsonape - 1.8655
# Hạng 839: AltCryptoGems - 1.8619
# Hạng 840: groove_on_x - 1.8615
# Hạng 841: JRNYGallery - 1.8601
# Hạng 842: jpgxfm - 1.8592
# Hạng 843: star_okx - 1.8586
# Hạng 844: TheSmolTalk - 1.8584
# Hạng 845: girl_intheverse - 1.8548
# Hạng 846: potuz_eth - 1.8544
# Hạng 847: Torero_Romero - 1.8539
# Hạng 848: KyleSamani - 1.8539
# Hạng 849: L0laL33tz - 1.8535
# Hạng 850: Awawat_Trades - 1.8524
# Hạng 851: Loopifyyy - 1.8520
# Hạng 852: nft_clctr - 1.8507
# Hạng 853: CodyCarboneDC - 1.8499
# Hạng 854: Defi0xJeff - 1.8489
# Hạng 855: cbventures - 1.8453
# Hạng 856: MOBCollective_ - 1.8446
# Hạng 857: HouriNaeimi - 1.8428
# Hạng 858: RachelSTWood - 1.8413
# Hạng 859: popilart - 1.8411
# Hạng 860: Punk9277 - 1.8405
# Hạng 861: hausoftiffany - 1.8401
# Hạng 862: DancingEddie_ - 1.8398
# Hạng 863: billyrestey - 1.8390
# Hạng 864: jared_poz - 1.8375
# Hạng 865: playmatejaylene - 1.8358
# Hạng 866: krybharat - 1.8322
# Hạng 867: wassie - 1.8310
# Hạng 868: zerokn0wledge_ - 1.8246
# Hạng 869: 0xVEER - 1.8246
# Hạng 870: IWannabeeNFT - 1.8229
# Hạng 871: realbatdad - 1.8226
# Hạng 872: goroishihata - 1.8222
# Hạng 873: MacroScope17 - 1.8218
# Hạng 874: moonsheepverse - 1.8205
# Hạng 875: Zaptio - 1.8167
# Hạng 876: juanpalaciosx - 1.8167
# Hạng 877: 0xPrismatic - 1.8135
# Hạng 878: 0xtaetaehoho - 1.8091
# Hạng 879: Plazma0x - 1.8078
# Hạng 880: spencer - 1.8069
# Hạng 881: 0xArch - 1.8051
# Hạng 882: rebeccarosenft - 1.8041
# Hạng 883: sorrisopng - 1.7970
# Hạng 884: MarkYusko - 1.7970
# Hạng 885: astamcloud - 1.7967
# Hạng 886: BoysClubWorld - 1.7949
# Hạng 887: Flowslikeosmo - 1.7941
# Hạng 888: AaronTeng - 1.7895
# Hạng 889: AaronHaber - 1.7848
# Hạng 890: AtownBrown - 1.7846
# Hạng 891: Justin_Bons - 1.7842
# Hạng 892: jbondwagon - 1.7814
# Hạng 893: TheRealRicoy - 1.7812
# Hạng 894: doodlifts - 1.7805
# Hạng 895: cryptohydrate - 1.7793
# Hạng 896: alphawifhat - 1.7734
# Hạng 897: builtnpublicpod - 1.7731
# Hạng 898: ShiLLin_ViLLian - 1.7711
# Hạng 899: trameparis - 1.7701
# Hạng 900: todayindefi - 1.7673
# Hạng 901: ki_young_ju - 1.7669
# Hạng 902: 0xPatchara - 1.7649
# Hạng 903: dogdamassa - 1.7629
# Hạng 904: Julio_tnim - 1.7627
# Hạng 905: ByzGeneral - 1.7603
# Hạng 906: cozmonika_art - 1.7591
# Hạng 907: alpha_pls - 1.7585
# Hạng 908: FFVV1211 - 1.7572
# Hạng 909: TsubasaRVonTG - 1.7560
# Hạng 910: _blockbird - 1.7552
# Hạng 911: ItsAlwaysZonny - 1.7549
# Hạng 912: lifofifo - 1.7548
# Hạng 913: 0xvisitor - 1.7523
# Hạng 914: VirtualBacon0x - 1.7517
# Hạng 915: SlorgoftheSlugs - 1.7503
# Hạng 916: PerianneDC - 1.7493
# Hạng 917: WazzCrypto - 1.7473
# Hạng 918: MarcellxMarcell - 1.7467
# Hạng 919: marek_ - 1.7425
# Hạng 920: 0xFiyopi - 1.7389
# Hạng 921: lucianaguerraok - 1.7380
# Hạng 922: MPtherealmvp - 1.7371
# Hạng 923: ClaireSilver12 - 1.7370
# Hạng 924: SpikeCollects - 1.7370
# Hạng 925: RachelConlan - 1.7342
# Hạng 926: billmondays - 1.7338
# Hạng 927: cited - 1.7302
# Hạng 928: SirGnarlGnomie - 1.7300
# Hạng 929: TakayamaJoe - 1.7294
# Hạng 930: OneLoveArtDAO - 1.7283
# Hạng 931: cryptoleon_xyz - 1.7276
# Hạng 932: austin_hurwitz - 1.7267
# Hạng 933: MaxisClub - 1.7221
# Hạng 934: Mash_CT - 1.7204
# Hạng 935: The4thWayYT - 1.7203
# Hạng 936: Fityeth - 1.7182
# Hạng 937: BamMetaX - 1.7155
# Hạng 938: ceterispar1bus - 1.7151
# Hạng 939: LongHashVC - 1.7148
# Hạng 940: Geiger_Capital - 1.7145
# Hạng 941: solananew - 1.7144
# Hạng 942: post_polar_ - 1.7140
# Hạng 943: __bleeker - 1.7130
# Hạng 944: DefiIgnas - 1.7128
# Hạng 945: DrSolanaNFT - 1.7114
# Hạng 946: CryptoVonDoom - 1.7112
# Hạng 947: ekang426 - 1.7100
# Hạng 948: palpalNFT - 1.7064
# Hạng 949: 0xdirichlet - 1.7053
# Hạng 950: devrelius - 1.7024
# Hạng 951: amber_vittoria - 1.7016
# Hạng 952: CryptoZachLA - 1.7011
# Hạng 953: jvb_xyz - 1.7004
# Hạng 954: MinisterOfNFTs - 1.6988
# Hạng 955: sandeepnailwal - 1.6941
# Hạng 956: DolcePaganne - 1.6935
# Hạng 957: ArtvisionNFT - 1.6931
# Hạng 958: packyM - 1.6930
# Hạng 959: benskaarphoto - 1.6909
# Hạng 960: bosscat1313 - 1.6872
# Hạng 961: MuroCrypto - 1.6867
# Hạng 962: paytkaleiwahea - 1.6863
# Hạng 963: mung0x - 1.6857
# Hạng 964: y2kappa - 1.6845
# Hạng 965: OmilliTees - 1.6836
# Hạng 966: akaFoley - 1.6792
# Hạng 967: SamuraiSpirit88 - 1.6782
# Hạng 968: C0MPUTERBL00D - 1.6780
# Hạng 969: phtevenstrong - 1.6780
# Hạng 970: buyerofponzi - 1.6752
# Hạng 971: TheMisfits___ - 1.6717
# Hạng 972: Palgrani2 - 1.6701
# Hạng 973: RachelOnchain - 1.6665
# Hạng 974: iamarkdev - 1.6663
# Hạng 975: Iamamystreet - 1.6576
# Hạng 976: austinreid21 - 1.6561
# Hạng 977: VanArman - 1.6549
# Hạng 978: RationalGaze__ - 1.6526
# Hạng 979: SolanaLegend - 1.6506
# Hạng 980: MetaLawMan - 1.6498
# Hạng 981: stacy_muur - 1.6489
# Hạng 982: ai - 1.6483
# Hạng 983: Narodism - 1.6472
# Hạng 984: purrlabs - 1.6438
# Hạng 985: Trader_XO - 1.6427
# Hạng 986: yourfriendSOMMI - 1.6366
# Hạng 987: cebolander - 1.6365
# Hạng 988: TheCryptoNexus - 1.6337
# Hạng 989: upnextboys - 1.6310
# Hạng 990: lifeofc - 1.6297
# Hạng 991: peekcell - 1.6293
# Hạng 992: Crypto_Scofield - 1.6288
# Hạng 993: niftyq_ - 1.6282
# Hạng 994: paddi_hansen - 1.6280
# Hạng 995: RonnyyGuyy - 1.6272
# Hạng 996: PrimordialAA - 1.6263
# Hạng 997: neutanent - 1.6261
# Hạng 998: SwagrMan - 1.6252
# Hạng 999: _choppingblock - 1.6235
# Hạng 1000: 0xMantleJP - 1.6232
# Hạng 1001: kevinabosch - 1.6185
# Hạng 1002: LoganJastremski - 1.6178
# Hạng 1003: jkrdoc - 1.6161
# Hạng 1004: BrutalS81 - 1.6145
# Hạng 1005: DexGemsReal - 1.6120
# Hạng 1006: matto__matto - 1.6112
# Hạng 1007: craigdoesweb3 - 1.6108
# Hạng 1008: SuperteamAE - 1.6100
# Hạng 1009: belikeblob - 1.6090
# Hạng 1010: BR4ted - 1.6076
# Hạng 1011: rom1_pellerin - 1.6059
# Hạng 1012: 0xkyle__ - 1.6059
# Hạng 1013: cardano_whale - 1.6045
# Hạng 1014: sharafi_eth - 1.6036
# Hạng 1015: ieatjeets - 1.6026
# Hạng 1016: fvckrender - 1.6017
# Hạng 1017: artxcode_io - 1.6006
# Hạng 1018: NFTCHESUS - 1.5978
# Hạng 1019: Yousstone766 - 1.5973
# Hạng 1020: CryptoJelleNL - 1.5969
# Hạng 1021: kyle_chasse - 1.5962
# Hạng 1022: jacobdotsol - 1.5961
# Hạng 1023: bitcoinwizardry - 1.5929
# Hạng 1024: CyrusAbrahimX - 1.5928
# Hạng 1025: MoonOverlord - 1.5923
# Hạng 1026: angrycryptoshow - 1.5911
# Hạng 1027: heidichristne - 1.5911
# Hạng 1028: otherguydoteth - 1.5894
# Hạng 1029: nixeniego - 1.5839
# Hạng 1030: ericonomic - 1.5831
# Hạng 1031: mryxji - 1.5824
# Hạng 1032: dielamaharanie - 1.5813
# Hạng 1033: bronzeageshawty - 1.5802
# Hạng 1034: BoyaGeorge - 1.5762
# Hạng 1035: CoinGurruu - 1.5761
# Hạng 1036: DarrenSRS - 1.5758
# Hạng 1037: Bonecondor - 1.5746
# Hạng 1038: totherootz - 1.5725
# Hạng 1039: JohnReedStark - 1.5725
# Hạng 1040: Frens_Factory - 1.5703
# Hạng 1041: WestieCapital - 1.5691
# Hạng 1042: jeetassassin - 1.5677
# Hạng 1043: schauermannx2 - 1.5660
# Hạng 1044: checksvv - 1.5637
# Hạng 1045: frankcorva - 1.5634
# Hạng 1046: functi0nZer0 - 1.5633
# Hạng 1047: IcedKnife - 1.5632
# Hạng 1048: MABLABART - 1.5596
# Hạng 1049: ts_hodl - 1.5582
# Hạng 1050: BobbiBicker - 1.5579
# Hạng 1051: EmporiumToken - 1.5574
# Hạng 1052: WokuWeekly - 1.5571
# Hạng 1053: whosknave - 1.5569
# Hạng 1054: DarranGarnham - 1.5566
# Hạng 1055: gabrielhaines - 1.5566
# Hạng 1056: honey_xbt - 1.5554
# Hạng 1057: dwaeloee - 1.5516
# Hạng 1058: based_d0m - 1.5510
# Hạng 1059: vwestphoto_nb - 1.5505
# Hạng 1060: ALPHACOETH - 1.5502
# Hạng 1061: ethermage - 1.5499
# Hạng 1062: BHAREBOY - 1.5488
# Hạng 1063: coinjoined - 1.5457
# Hạng 1064: KittenHaimer - 1.5456
# Hạng 1065: PaulFrambot - 1.5449
# Hạng 1066: iamlaurael - 1.5426
# Hạng 1067: MatthewHyland_ - 1.5416
# Hạng 1068: FLC_FlooringLab - 1.5383
# Hạng 1069: danielgothits - 1.5375
# Hạng 1070: paik_michael - 1.5355
# Hạng 1071: OnchainHQ - 1.5351
# Hạng 1072: cathsimard_ - 1.5330
# Hạng 1073: Cabanimation - 1.5326
# Hạng 1074: DanPaul000 - 1.5301
# Hạng 1075: AEB_NFT - 1.5300
# Hạng 1076: ZeMirch - 1.5288
# Hạng 1077: MLGsolana420 - 1.5285
# Hạng 1078: KitsuSun - 1.5284
# Hạng 1079: aspenshredder - 1.5271
# Hạng 1080: FlashX - 1.5271
# Hạng 1081: anndylian - 1.5262
# Hạng 1082: moo9000 - 1.5243
# Hạng 1083: MrScottSheridan - 1.5238
# Hạng 1084: retardio_paine - 1.5235
# Hạng 1085: WLitecoin - 1.5225
# Hạng 1086: cyphergenesisAI - 1.5224
# Hạng 1087: fkpxls - 1.5223
# Hạng 1088: panicselling - 1.5198
# Hạng 1089: AmirMushich - 1.5185
# Hạng 1090: tahaabbasi - 1.5183
# Hạng 1091: kokocodes - 1.5180
# Hạng 1092: blancxbt - 1.5166
# Hạng 1093: anna_kazlauskas - 1.5116
# Hạng 1094: B_daojia - 1.5076
# Hạng 1095: pierskicks - 1.5068
# Hạng 1096: DeRonin_ - 1.5068
# Hạng 1097: 0rdlibrary - 1.5068
# Hạng 1098: trent_vanepps - 1.5062
# Hạng 1099: KWEEN_SOL - 1.5053
# Hạng 1100: BIGgrits100 - 1.5047
# Hạng 1101: NegativeVibrat1 - 1.5040
# Hạng 1102: tonyplasencia3 - 1.5018
# Hạng 1103: Mamba248x - 1.5015
# Hạng 1104: traderpow - 1.5014
# Hạng 1105: INVESTIRDOZERO - 1.5003
# Hạng 1106: AaronRDay - 1.4996
# Hạng 1107: AveryChing - 1.4958
# Hạng 1108: mattob_eth - 1.4938
# Hạng 1109: ApolloDoge - 1.4928
# Hạng 1110: Brongis9163 - 1.4927
# Hạng 1111: huntclubhero - 1.4905
# Hạng 1112: saintsonso - 1.4893
# Hạng 1113: valeriesocials - 1.4881
# Hạng 1114: cursedskittles - 1.4873
# Hạng 1115: stekisteks - 1.4869
# Hạng 1116: lemiscate - 1.4863
# Hạng 1117: Liifebeats - 1.4861
# Hạng 1118: Alanfalcon - 1.4855
# Hạng 1119: VegetaCrypto1 - 1.4852
# Hạng 1120: jakegallen_ - 1.4836
# Hạng 1121: phillip_xyz - 1.4820
# Hạng 1122: cryptoaladeen - 1.4814
# Hạng 1123: IamNomad - 1.4810
# Hạng 1124: graildoteth - 1.4802
# Hạng 1125: endangered_SOL - 1.4784
# Hạng 1126: Shaughnessy119 - 1.4763
# Hạng 1127: spacefroot - 1.4749
# Hạng 1128: stopstare - 1.4745
# Hạng 1129: HighCoinviction - 1.4739
# Hạng 1130: Viorika_art - 1.4734
# Hạng 1131: BrenzCrypto - 1.4698
# Hạng 1132: Sir_Damilare - 1.4688
# Hạng 1133: VioletBondArt - 1.4683
# Hạng 1134: aljaparis - 1.4679
# Hạng 1135: swasti_art - 1.4662
# Hạng 1136: Jebus - 1.4659
# Hạng 1137: MilkRoadDaily - 1.4637
# Hạng 1138: TommyTwoClubs - 1.4628
# Hạng 1139: insertdisclaimr - 1.4614
# Hạng 1140: YGGPilipinas - 1.4599
# Hạng 1141: rayan_oncyber - 1.4575
# Hạng 1142: mmwalk - 1.4564
# Hạng 1143: StarPlatinumSOL - 1.4546
# Hạng 1144: mezoteric - 1.4524
# Hạng 1145: ShisuiXBT - 1.4520
# Hạng 1146: Timccopeland - 1.4489
# Hạng 1147: obchakevich_ - 1.4459
# Hạng 1148: _Checkmatey_ - 1.4455
# Hạng 1149: songadaymann - 1.4446
# Hạng 1150: TheRoninRadio - 1.4443
# Hạng 1151: palekirill - 1.4424
# Hạng 1152: CryptoTalkMan - 1.4424
# Hạng 1153: TheShibmagazine - 1.4417
# Hạng 1154: AdonisOnX - 1.4412
# Hạng 1155: ram_dezin - 1.4410
# Hạng 1156: lazyvillager1 - 1.4400
# Hạng 1157: _0xQuan - 1.4398
# Hạng 1158: bikutaaRON - 1.4386
# Hạng 1159: Nicolas_Sassoon - 1.4381
# Hạng 1160: Irenezhao_ - 1.4376
# Hạng 1161: NotChaseColeman - 1.4362
# Hạng 1162: Credible_Chr1s - 1.4342
# Hạng 1163: Hantao - 1.4338
# Hạng 1164: cryptosheep_eth - 1.4335
# Hạng 1165: Crypto_Colombus - 1.4331
# Hạng 1166: HyperFND - 1.4329
# Hạng 1167: camiinthisthang - 1.4322
# Hạng 1168: 0xsmac - 1.4308
# Hạng 1169: danheld - 1.4305
# Hạng 1170: rhmattson - 1.4304
# Hạng 1171: JoeNakamoto - 1.4278
# Hạng 1172: IamGhost_AF - 1.4273
# Hạng 1173: BastilleBtc - 1.4265
# Hạng 1174: CryptMonsters_ - 1.4255
# Hạng 1175: Pampadalampa - 1.4250
# Hạng 1176: NiqadyMaker - 1.4249
# Hạng 1177: dsanka9 - 1.4239
# Hạng 1178: patrdoy - 1.4232
# Hạng 1179: CashAnvil - 1.4216
# Hạng 1180: sbtwolf - 1.4205
# Hạng 1181: 0xKepler - 1.4191
# Hạng 1182: vladtenev - 1.4157
# Hạng 1183: buridanova - 1.4148
# Hạng 1184: Crypto_McKenna - 1.4144
# Hạng 1185: ROBNESSOFFICIAL - 1.4126
# Hạng 1186: kodama_eth - 1.4120
# Hạng 1187: tetonotsorry - 1.4115
# Hạng 1188: ChrisCoffeeEth - 1.4103
# Hạng 1189: defi_monk - 1.4103
# Hạng 1190: revolut20 - 1.4093
# Hạng 1191: PeterMcCormack - 1.4087
# Hạng 1192: 973Meech - 1.4068
# Hạng 1193: deltaxbt - 1.4050
# Hạng 1194: SRKTK56 - 1.4040
# Hạng 1195: Zac_Aztec - 1.4038
# Hạng 1196: Phin_totten - 1.4028
# Hạng 1197: SolanaPlays - 1.4023
# Hạng 1198: bonafidehan - 1.4004
# Hạng 1199: btcpolicyorg - 1.3996
# Hạng 1200: 0xmaz_ - 1.3968
# Hạng 1201: 6529er - 1.3962
# Hạng 1202: EstherDavi54981 - 1.3960
# Hạng 1203: tervoooo - 1.3960
# Hạng 1204: Ape_31 - 1.3957
# Hạng 1205: 0FJAKE - 1.3955
# Hạng 1206: pos2only - 1.3955
# Hạng 1207: anildelphi - 1.3954
# Hạng 1208: FonzGm - 1.3945
# Hạng 1209: CryptoTea_ - 1.3925
# Hạng 1210: MonteKriptoKont - 1.3924
# Hạng 1211: piv_piv - 1.3914
# Hạng 1212: StashInu - 1.3911
# Hạng 1213: TwonXBT - 1.3902
# Hạng 1214: vivid_ordinals - 1.3888
# Hạng 1215: stackhodler - 1.3885
# Hạng 1216: CoinbaseDuck - 1.3873
# Hạng 1217: YagamiTailor - 1.3870
# Hạng 1218: QuintenFrancois - 1.3863
# Hạng 1219: NedRyersonBing - 1.3851
# Hạng 1220: andycoinonerc - 1.3850
# Hạng 1221: tankabagnale - 1.3836
# Hạng 1222: NoelleInMadrid - 1.3834
# Hạng 1223: tuukzs - 1.3818
# Hạng 1224: Bastienjpg - 1.3789
# Hạng 1225: macbrennan_cc - 1.3784
# Hạng 1226: chalchuqi - 1.3778
# Hạng 1227: MikeyTrading - 1.3777
# Hạng 1228: MentorNotPseudo - 1.3773
# Hạng 1229: itsGboii - 1.3758
# Hạng 1230: ernestleedotcom - 1.3741
# Hạng 1231: 9gagceo - 1.3736
# Hạng 1232: GraceNft89 - 1.3729
# Hạng 1233: UToobCoin - 1.3727
# Hạng 1234: AryaWirawans - 1.3717
# Hạng 1235: kurogod5 - 1.3711
# Hạng 1236: natemodi - 1.3708
# Hạng 1237: crypto_condom - 1.3702
# Hạng 1238: tylerdurdeth - 1.3685
# Hạng 1239: TusharJain_ - 1.3684
# Hạng 1240: theo_crypto99 - 1.3675
# Hạng 1241: matdryhurst - 1.3670
# Hạng 1242: WayneVaughan - 1.3665
# Hạng 1243: jmpailhon - 1.3641
# Hạng 1244: rajatsonifnance - 1.3636
# Hạng 1245: EmilyLazar_SM - 1.3616
# Hạng 1246: anon_rip - 1.3610
# Hạng 1247: eth_apple - 1.3609
# Hạng 1248: streetcyber_art - 1.3601
# Hạng 1249: bykellymcd - 1.3601
# Hạng 1250: Ordinals_Al - 1.3597
# Hạng 1251: kayvan2sfo - 1.3593
# Hạng 1252: iamasifr - 1.3571
# Hạng 1253: nicedayJules - 1.3558
# Hạng 1254: 0xAbhiP - 1.3546
# Hạng 1255: coopernicus01 - 1.3542
# Hạng 1256: nazimahmed - 1.3521
# Hạng 1257: designzbychance - 1.3521
# Hạng 1258: lizardvampire - 1.3516
# Hạng 1259: Carl_m101 - 1.3516
# Hạng 1260: old_soon - 1.3513
# Hạng 1261: novogratz - 1.3510
# Hạng 1262: z0r0zzz - 1.3503
# Hạng 1263: Bitaemm - 1.3476
# Hạng 1264: BSCGemsAlert - 1.3470
# Hạng 1265: SuperteamUK - 1.3469
# Hạng 1266: winnyeth - 1.3451
# Hạng 1267: jesusdoteth - 1.3448
# Hạng 1268: NumberOnePengu - 1.3447
# Hạng 1269: CloutedMind - 1.3428
# Hạng 1270: OrdinalsNexus - 1.3425
# Hạng 1271: WGMeets - 1.3423
# Hạng 1272: loomdart - 1.3419
# Hạng 1273: V1Zhual - 1.3412
# Hạng 1274: mondoggg - 1.3404
# Hạng 1275: CryptoGemRnld - 1.3401
# Hạng 1276: TGer_01 - 1.3401
# Hạng 1277: rudxane1 - 1.3397
# Hạng 1278: karan4d - 1.3385
# Hạng 1279: zackbshapiro - 1.3375
# Hạng 1280: Karanpal25 - 1.3367
# Hạng 1281: AndreCronjeTech - 1.3355
# Hạng 1282: TheOrdinalShow - 1.3338
# Hạng 1283: DonnyDicey - 1.3320
# Hạng 1284: YuzoKano - 1.3310
# Hạng 1285: Vickilicious10 - 1.3298
# Hạng 1286: blckchaindaily - 1.3292
# Hạng 1287: NicoleBehnam - 1.3291
# Hạng 1288: Mireyita_art - 1.3290
# Hạng 1289: kkashi_yt - 1.3285
# Hạng 1290: spogelsemaskine - 1.3283
# Hạng 1291: jeffjohnroberts - 1.3268
# Hạng 1292: AdamWeitsman - 1.3267
# Hạng 1293: Haider - 1.3259
# Hạng 1294: mikeygnft - 1.3255
# Hạng 1295: 0xNing0x - 1.3254
# Hạng 1296: AllStreetBets - 1.3253
# Hạng 1297: peterschroederr - 1.3247
# Hạng 1298: rektober - 1.3245
# Hạng 1299: PepeEternal - 1.3238
# Hạng 1300: mymoda_io - 1.3235
# Hạng 1301: koeppelmann - 1.3219
# Hạng 1302: shurivich - 1.3216
# Hạng 1303: lucianlampdefi - 1.3215
# Hạng 1304: AshAEgan - 1.3215
# Hạng 1305: lucithecoin - 1.3213
# Hạng 1306: GuyNorcal - 1.3212
# Hạng 1307: varunsrin - 1.3200
# Hạng 1308: matteodotsui - 1.3188
# Hạng 1309: daumeneth - 1.3187
# Hạng 1310: Daryllautk - 1.3180
# Hạng 1311: HoizonArt - 1.3179
# Hạng 1312: DannyDegens - 1.3176
# Hạng 1313: RoguesNFT - 1.3171
# Hạng 1314: CoinSeer - 1.3154
# Hạng 1315: FrothlessPlease - 1.3131
# Hạng 1316: PhantomBP_giga - 1.3122
# Hạng 1317: SmolMobster - 1.3110
# Hạng 1318: colorful_masic - 1.3101
# Hạng 1319: solkcrow - 1.3099
# Hạng 1320: Shibtoshi_SG - 1.3097
# Hạng 1321: pippinlovesyou - 1.3096
# Hạng 1322: nft_dreww - 1.3095
# Hạng 1323: Web3Maxx - 1.3086
# Hạng 1324: lennyjpg - 1.3084
# Hạng 1325: 5tr4n0 - 1.3084
# Hạng 1326: techbubble - 1.3082
# Hạng 1327: cryptomattk - 1.3079
# Hạng 1328: postanika - 1.3064
# Hạng 1329: ThinkingCrypto1 - 1.3057
# Hạng 1330: Pirate_Angel_ - 1.3054
# Hạng 1331: basednetpanda - 1.3051
# Hạng 1332: hackernoon - 1.3051
# Hạng 1333: blockgraze - 1.3050
# Hạng 1334: theshikhai - 1.3049
# Hạng 1335: auntygingy - 1.3047
# Hạng 1336: SWEATY333 - 1.3047
# Hạng 1337: crypto_adair - 1.3044
# Hạng 1338: ValeBrent - 1.3042
# Hạng 1339: MrSushihat - 1.3039
# Hạng 1340: lokithebird - 1.3036
# Hạng 1341: ugliestduck - 1.3033
# Hạng 1342: DaBunnyOFFICIAL - 1.3028
# Hạng 1343: apcollectiveio - 1.2999
# Hạng 1344: LeslieM0tta - 1.2999
# Hạng 1345: JoshuaTobkin - 1.2985
# Hạng 1346: Mariuscarl1 - 1.2970
# Hạng 1347: mydiscocats - 1.2969
# Hạng 1348: ElizabethOls0n - 1.2949
# Hạng 1349: melgibsonfan99 - 1.2927
# Hạng 1350: S0LFRED - 1.2924
# Hạng 1351: DeeHouseMF - 1.2859
# Hạng 1352: YuichiMukai3 - 1.2853
# Hạng 1353: ALIENQUEENNFT - 1.2852
# Hạng 1354: Vega0x - 1.2835
# Hạng 1355: rata_yonqui - 1.2823
# Hạng 1356: Hildabroom7 - 1.2822
# Hạng 1357: 0xResearch - 1.2816
# Hạng 1358: optimizoor - 1.2815
# Hạng 1359: ihrimi2115 - 1.2791
# Hạng 1360: ashikayui - 1.2790
# Hạng 1361: TheiaResearch - 1.2790
# Hạng 1362: valueandtime - 1.2788
# Hạng 1363: cypheristikal - 1.2780
# Hạng 1364: apixtwts - 1.2769
# Hạng 1365: 0xFonzy - 1.2760
# Hạng 1366: IvanOnTech - 1.2748
# Hạng 1367: The_Daily_Alpha - 1.2731
# Hạng 1368: EmpressTrash - 1.2731
# Hạng 1369: p1xelfool - 1.2728
# Hạng 1370: hal2001 - 1.2727
# Hạng 1371: TimeofEmergence - 1.2724
# Hạng 1372: chivasweb3 - 1.2720
# Hạng 1373: megan_crypto - 1.2718
# Hạng 1374: narisofka - 1.2709
# Hạng 1375: MatDefies - 1.2705
# Hạng 1376: adamscochran - 1.2696
# Hạng 1377: daniloxhema - 1.2676
# Hạng 1378: jadler0 - 1.2674
# Hạng 1379: ProofOfTravis - 1.2674
# Hạng 1380: new_world_you - 1.2673
# Hạng 1381: 10xdegendev - 1.2665
# Hạng 1382: chepertom - 1.2663
# Hạng 1383: sanjfomojis - 1.2651
# Hạng 1384: IAmNickDodson - 1.2648
# Hạng 1385: Nofuturephoto - 1.2645
# Hạng 1386: BigNillCollect - 1.2640
# Hạng 1387: stvngts - 1.2639
# Hạng 1388: blond_ish - 1.2635
# Hạng 1389: mztacat - 1.2630
# Hạng 1390: nftkoosh - 1.2610
# Hạng 1391: andy8052 - 1.2606
# Hạng 1392: nftsandkids - 1.2585
# Hạng 1393: slander_eth - 1.2579
# Hạng 1394: delucinator - 1.2570
# Hạng 1395: josemvcerqueira - 1.2569
# Hạng 1396: neonglitch86 - 1.2561
# Hạng 1397: ApetoonStudios - 1.2560
# Hạng 1398: chrono_chartist - 1.2560
# Hạng 1399: _Necro_Void_ - 1.2548
# Hạng 1400: lukoart_ - 1.2540
# Hạng 1401: spunosounds - 1.2535
# Hạng 1402: yomuyakadashi - 1.2527
# Hạng 1403: hfangca - 1.2525
# Hạng 1404: 0xRodo - 1.2516
# Hạng 1405: digijointz - 1.2510
# Hạng 1406: TravelSwap_xyz - 1.2509
# Hạng 1407: therealchaseeb - 1.2506
# Hạng 1408: Data_Always - 1.2486
# Hạng 1409: semicondurian - 1.2482
# Hạng 1410: TradesIndustry_ - 1.2481
# Hạng 1411: TheCultSeries - 1.2480
# Hạng 1412: ElderKarl68 - 1.2465
# Hạng 1413: smsonx - 1.2464
# Hạng 1414: omz_nft - 1.2461
# Hạng 1415: Crypto4MePlz - 1.2451
# Hạng 1416: ImBrendanNorth - 1.2449
# Hạng 1417: YQNFT - 1.2442
# Hạng 1418: BankeraDao - 1.2431
# Hạng 1419: Croginal - 1.2426
# Hạng 1420: bearsnake_21 - 1.2419
# Hạng 1421: dianabinance - 1.2418
# Hạng 1422: CappyCollective - 1.2410
# Hạng 1423: sjdedic - 1.2408
# Hạng 1424: Xiznft - 1.2401
# Hạng 1425: IgnitionFBTC - 1.2386
# Hạng 1426: 6oryachikh - 1.2379
# Hạng 1427: Degen_NFT_VN - 1.2375
# Hạng 1428: toshinobu_nft - 1.2375
# Hạng 1429: SCUMSOL - 1.2366
# Hạng 1430: aida_studios - 1.2357
# Hạng 1431: RadiantsDAO - 1.2357
# Hạng 1432: zen_llama - 1.2356
# Hạng 1433: ArtistDutchArt - 1.2355
# Hạng 1434: kitahara_keiko - 1.2352
# Hạng 1435: smokethatdank1 - 1.2352
# Hạng 1436: 0xLawl - 1.2351
# Hạng 1437: Toos_pooky - 1.2348
# Hạng 1438: Slappjakke - 1.2340
# Hạng 1439: DZNTS_NFT - 1.2339
# Hạng 1440: Nomaticcap - 1.2338
# Hạng 1441: JUPANDJUICE - 1.2321
# Hạng 1442: meximalist - 1.2315
# Hạng 1443: fungibIes - 1.2311
# Hạng 1444: smatthewschultz - 1.2297
# Hạng 1445: phantom_scribbs - 1.2294
# Hạng 1446: muneeb - 1.2292
# Hạng 1447: web3_honey - 1.2291
# Hạng 1448: Rikbitz - 1.2274
# Hạng 1449: AlexKittoe - 1.2268
# Hạng 1450: Hackatao - 1.2261
# Hạng 1451: DonCryptonium - 1.2257
# Hạng 1452: larpalt - 1.2253
# Hạng 1453: SLEEPYTIME3M - 1.2252
# Hạng 1454: AfroBitcoinOrg - 1.2249
# Hạng 1455: NatChittamai - 1.2227
# Hạng 1456: R89Capital - 1.2224
# Hạng 1457: Rahim_mahtab - 1.2212
# Hạng 1458: karelvuong - 1.2210
# Hạng 1459: CryptoShawn88 - 1.2207
# Hạng 1460: PunkBezos - 1.2200
# Hạng 1461: CryptoeJammin - 1.2199
# Hạng 1462: KingOnEth - 1.2195
# Hạng 1463: ammar_zaeem - 1.2195
# Hạng 1464: pukecast - 1.2192
# Hạng 1465: Rrose_Selavy_11 - 1.2192
# Hạng 1466: Evan_ss6 - 1.2182
# Hạng 1467: gauthamzzz - 1.2168
# Hạng 1468: jpeggler - 1.2159
# Hạng 1469: Bitcoin_Teddy - 1.2159
# Hạng 1470: JohnNahas84 - 1.2154
# Hạng 1471: chenbfang - 1.2139
# Hạng 1472: iannocent - 1.2127
# Hạng 1473: canekzapata - 1.2126
# Hạng 1474: Solopopsss - 1.2124
# Hạng 1475: getderb - 1.2118
# Hạng 1476: rekt2160 - 1.2112
# Hạng 1477: nafata14 - 1.2107
# Hạng 1478: breakingbarbie - 1.2105
# Hạng 1479: ClaireFirley - 1.2099
# Hạng 1480: JPEGreg - 1.2094
# Hạng 1481: 0xUn1c0rn - 1.2094
# Hạng 1482: grossehalbuer - 1.2087
# Hạng 1483: Linkkzyy - 1.2086
# Hạng 1484: degengambleh - 1.2075
# Hạng 1485: OCBalpha - 1.2074
# Hạng 1486: narcisojuse - 1.2052
# Hạng 1487: ysksdr - 1.2051
# Hạng 1488: brodyadreon - 1.2050
# Hạng 1489: HLF_ID40118756 - 1.2049
# Hạng 1490: absurdeity - 1.2043
# Hạng 1491: chainszy - 1.2031
# Hạng 1492: CarlBMenger - 1.2016
# Hạng 1493: Hemdawg_ - 1.2013
# Hạng 1494: OtakuLabs_xyz - 1.2003
# Hạng 1495: cry_curr_ar - 1.1993
# Hạng 1496: zhusu - 1.1988
# Hạng 1497: theempirepod - 1.1984
# Hạng 1498: zhang_matt - 1.1981
# Hạng 1499: sungmo_nad - 1.1979
# Hạng 1500: 0xAA_Science - 1.1979
# Hạng 1501: nftbawsa - 1.1977
# Hạng 1502: forcethehabit - 1.1977
# Hạng 1503: Baby__BTC - 1.1969
# Hạng 1504: calilyliu - 1.1946
# Hạng 1505: fizzlestixx21e8 - 1.1938
# Hạng 1506: METHHEDZ - 1.1935
# Hạng 1507: miboso__ - 1.1923
# Hạng 1508: 0xMontBlanc - 1.1920
# Hạng 1509: ZenithTON - 1.1914
# Hạng 1510: KingWilliamDefi - 1.1909
# Hạng 1511: nubcat - 1.1908
# Hạng 1512: tobynovum - 1.1902
# Hạng 1513: DogOfBitcoin - 1.1900
# Hạng 1514: MorokitchBD - 1.1887
# Hạng 1515: mashiiiine - 1.1874
# Hạng 1516: callebtc - 1.1858
# Hạng 1517: yatreda - 1.1858
# Hạng 1518: TXMCtrades - 1.1855
# Hạng 1519: 0xFinish - 1.1842
# Hạng 1520: 0xMQQ - 1.1831
# Hạng 1521: solquicks - 1.1829
# Hạng 1522: DataGalerie - 1.1828
# Hạng 1523: donnoh_eth - 1.1796
# Hạng 1524: sashelka - 1.1790
# Hạng 1525: 0xKipit - 1.1769
# Hạng 1526: martypartymusic - 1.1764
# Hạng 1527: Rhynotic - 1.1756
# Hạng 1528: oliviapedi - 1.1756
# Hạng 1529: vasiamakris - 1.1753
# Hạng 1530: HalibutCrypto - 1.1743
# Hạng 1531: 0x_Abdul - 1.1736
# Hạng 1532: sssionggg - 1.1733
# Hạng 1533: KeithSingery - 1.1730
# Hạng 1534: megs_io - 1.1715
# Hạng 1535: Based_Uncle_Ted - 1.1709
# Hạng 1536: JakeBlockchain - 1.1702
# Hạng 1537: JakNFT - 1.1694
# Hạng 1538: i_am_jackis - 1.1692
# Hạng 1539: Cito_Zone - 1.1690
# Hạng 1540: aluxyeth - 1.1685
# Hạng 1541: drewtility - 1.1678
# Hạng 1542: EmpressRaeon - 1.1671
# Hạng 1543: efenigson - 1.1670
# Hạng 1544: Rob1Ham - 1.1670
# Hạng 1545: SilvXBT - 1.1668
# Hạng 1546: 0xFrisk - 1.1654
# Hạng 1547: GooseTheBAYC - 1.1654
# Hạng 1548: SolSniffer - 1.1648
# Hạng 1549: 0xMughal - 1.1637
# Hạng 1550: greenie_sr - 1.1611
# Hạng 1551: fukusta343 - 1.1610
# Hạng 1552: br0kegenius - 1.1596
# Hạng 1553: connorgrasso_ - 1.1585
# Hạng 1554: cousincrypt0 - 1.1578
# ...
# Hạng 19718: _DeFiVerse - 0.0907
# Hạng 19719: _Mishuman_ - 0.0907
# Hạng 19720: _Hroarr - 0.0907
# Hạng 19721: _H_P_D_ - 0.0907
# Hạng 19722: DeFinnTheFarmer - 0.0907
# Hạng 19723: _EWNS - 0.0907
# Hạng 19724: _DemBee - 0.0907
# Hạng 19725: _D__A__R__K__ - 0.0907
# Hạng 19726: _CROWNADE - 0.0907
# Hạng 19727: _CryptoRonin_ - 0.0907
# Hạng 19728: _CryptoFanz - 0.0907
# Hạng 19729: _CryptoCreamy - 0.0907
# Hạng 19730: Deadshot373 - 0.0907
# Hạng 19731: DeafDynamics_TC - 0.0907
# Hạng 19732: _ColesTrading - 0.0907
# Hạng 19733: DefiBoomslang - 0.0907
# Hạng 19734: DefiDeck - 0.0907
# Hạng 19735: DefiDividends - 0.0907
# Hạng 19736: YzzzH15 - 0.0907
# Hạng 19737: Zaddy_Fi - 0.0907
# Hạng 19738: ZachLight16 - 0.0907
# Hạng 19739: ZachBoychuk - 0.0907
# Hạng 19740: DegenBing - 0.0907
# Hạng 19741: ZZZZZFEHUZZZZZ - 0.0907
# Hạng 19742: ZELL1688 - 0.0907
# Hạng 19743: DegenFaragu - 0.0907
# Hạng 19744: ZainanZhou - 0.0907
# Hạng 19745: Yuyou_567 - 0.0907
# Hạng 19746: Yuntian88 - 0.0907
# Hạng 19747: DegenLexx - 0.0907
# Hạng 19748: Yugheldss - 0.0907
# Hạng 19749: Yudidost - 0.0907
# Hạng 19750: Youngabstract - 0.0907
# Hạng 19751: Defilaocunzhang - 0.0907
# Hạng 19752: ZaiynCrypto - 0.0907
# Hạng 19753: DefiFireQueen - 0.0907
# Hạng 19754: Zennxz - 0.0907
# Hạng 19755: DefiGuy101 - 0.0907
# Hạng 19756: ZhouYaYa - 0.0907
# Hạng 19757: ZeusXcorp - 0.0907
# Hạng 19758: ZeusNFTART888 - 0.0907
# Hạng 19759: ZeusCrypto_ - 0.0907
# Hạng 19760: DefiRaiders - 0.0907
# Hạng 19761: DefiTuff - 0.0907
# Hạng 19762: Zbindiesel - 0.0907
# Hạng 19763: Zemerwatches - 0.0907
# Hạng 19764: Defi_Deeva - 0.0907
# Hạng 19765: Defi_Demo - 0.0907
# Hạng 19766: Defi_Gemma001 - 0.0907
# Hạng 19767: Zdeadex - 0.0907
# Hạng 19768: Defi_Shiller1 - 0.0907
# Hạng 19769: WarrenMulletSPX - 0.0907
# Hạng 19770: WareHouse_Ronny - 0.0907
# Hạng 19771: _Quivira - 0.0907
# Hạng 19772: TravisTheApe - 0.0907
# Hạng 19773: TroyMurs - 0.0907
# Hạng 19774: TrissyCrypto - 0.0907
# Hạng 19775: TrippyLasers - 0.0907
# Hạng 19776: TrioDGT - 0.0907
# Hạng 19777: Trinity_sats - 0.0907
# Hạng 19778: TriniNFTs - 0.0907
# Hạng 19779: TribeOTF - 0.0907
# Hạng 19780: TriMaiMS - 0.0907
# Hạng 19781: TrevorsLessons - 0.0907
# Hạng 19782: DrChadCrypto - 0.0907
# Hạng 19783: DrEinstein9999 - 0.0907
# Hạng 19784: Trenchwarior - 0.0907
# Hạng 19785: TreezyBreezyNFT - 0.0907
# Hạng 19786: TreeCityWes - 0.0907
# Hạng 19787: DrJayDD - 0.0907
# Hạng 19788: TruongNguyenVD - 0.0907
# Hạng 19789: DotFrog30 - 0.0907
# Hạng 19790: Tsumutsumutsumy - 0.0907
# Hạng 19791: TusharPro333 - 0.0907
# Hạng 19792: TylerPro52 - 0.0907
# Hạng 19793: TylerDowdle - 0.0907
# Hạng 19794: DonteeWeaver - 0.0907
# Hạng 19795: Tyler2TheMoon - 0.0907
# Hạng 19796: Twumpcto - 0.0907
# Hạng 19797: DoomscrollerGMI - 0.0907
# Hạng 19798: Turkoinimchat - 0.0907
# Hạng 19799: TtNfTt_NFT_1 - 0.0907
# Hạng 19800: Tumblrswap - 0.0907
# Hạng 19801: Dorae_Sol2024 - 0.0907
# Hạng 19802: Tufanoglu_ - 0.0907
# Hạng 19803: TuanNguyen_6789 - 0.0907
# Hạng 19804: TuHuynh971 - 0.0907
# Hạng 19805: TuGouKing - 0.0907
# Hạng 19806: DrJeyo - 0.0907
# Hạng 19807: Trav_hube_shirt - 0.0907
# Hạng 19808: WardenChas - 0.0907
# Hạng 19809: Transsleila - 0.0907
# Hạng 19810: TomOverChaplin - 0.0907
# Hạng 19811: TokenMore - 0.0907
# Hạng 19812: DreamCrypto99 - 0.0907
# Hạng 19813: DreamInWeb3 - 0.0907
# Hạng 19814: ToddlerNFT - 0.0907
# Hạng 19815: Dreammakers66 - 0.0907
# Hạng 19816: ToastedBagel27 - 0.0907
# Hạng 19817: Tmac_SOL - 0.0907
# Hạng 19818: Tkhl_3 - 0.0907
# Hạng 19819: TitlePendnGames - 0.0907
# Hạng 19820: TinTinLand_ZH - 0.0907
# Hạng 19821: Timurkutayy - 0.0907
# Hạng 19822: DrewBleam - 0.0907
# Hạng 19823: DrewDove100x - 0.0907
# Hạng 19824: Timi11i - 0.0907
# Hạng 19825: TomWade - 0.0907
# Hạng 19826: TomWagmi - 0.0907
# Hạng 19827: TomasCrypt0 - 0.0907
# Hạng 19828: TonyDialgaX - 0.0907
# Hạng 19829: DrPayFi - 0.0907
# Hạng 19830: TradingByStorm - 0.0907
# Hạng 19831: Trader_Jibon - 0.0907
# Hạng 19832: TradeRFRM - 0.0907
# Hạng 19833: Touring540 - 0.0907
# Hạng 19834: Toretoo2017 - 0.0907
# Hạng 19835: ToniGhinea - 0.0907
# Hạng 19836: Dragoonneth - 0.0907
# Hạng 19837: Dr_PhillipB - 0.0907
# Hạng 19838: Tomsuper2870 - 0.0907
# Hạng 19839: Draca_3 - 0.0907
# Hạng 19840: TommyKingham - 0.0907
# Hạng 19841: DragonmasterETH - 0.0907
# Hạng 19842: TommyDeng_DAO - 0.0907
# Hạng 19843: Tymdan__ - 0.0907
# Hạng 19844: TyreksRoaaarrrr - 0.0907
# Hạng 19845: Don_Luvat - 0.0907
# Hạng 19846: DonMiguelDelSol - 0.0907
# Hạng 19847: VitalyDeLuxe - 0.0907
# Hạng 19848: Visual_eth - 0.0907
# Hạng 19849: DistilledCrypto - 0.0907
# Hạng 19850: Virtual_Market_ - 0.0907
# Hạng 19851: ViralDecadent - 0.0907
# Hạng 19852: DizzieBunny - 0.0907
# Hạng 19853: DizzyJammer - 0.0907
# Hạng 19854: DjPrestigeUk - 0.0907
# Hạng 19855: VincentXuEth - 0.0907
# Hạng 19856: VincentDCrypto - 0.0907
# Hạng 19857: Viewsvalidator - 0.0907
# Hạng 19858: View2blockchain - 0.0907
# Hạng 19859: Viettoan1798 - 0.0907
# Hạng 19860: VictoryCrypto1 - 0.0907
# Hạng 19861: Dleven_ - 0.0907
# Hạng 19862: Vitalz1000 - 0.0907
# Hạng 19863: VitoshiDan - 0.0907
# Hạng 19864: VooDooNemesi - 0.0907
# Hạng 19865: WTF_Fonzie - 0.0907
# Hạng 19866: Wallstreet_Ape - 0.0907
# Hạng 19867: WallStreet_WSC - 0.0907
# Hạng 19868: WakiyamaP - 0.0907
# Hạng 19869: DimitriDotEth - 0.0907
# Hạng 19870: Wahgmi - 0.0907
# Hạng 19871: WTF_is_Web3 - 0.0907
# Hạng 19872: WRabbit1111 - 0.0907
# Hạng 19873: VoxVex000 - 0.0907
# Hạng 19874: DiogoAndrea1 - 0.0907
# Hạng 19875: WAZIRIHBS - 0.0907
# Hạng 19876: W1ll1amEth - 0.0907
# Hạng 19877: Vu_Benson - 0.0907
# Hạng 19878: VtorVentura1 - 0.0907
# Hạng 19879: DippiesNFT - 0.0907
# Hạng 19880: VictorvCrypto - 0.0907
# Hạng 19881: Victimguy - 0.0907
# Hạng 19882: VickWowo - 0.0907
# Hạng 19883: UQ_sol - 0.0907
# Hạng 19884: UncleRy_ - 0.0907
# Hạng 19885: Dogi1313 - 0.0907
# Hạng 19886: Dogs8eggs - 0.0907
# Hạng 19887: Ujahchris2 - 0.0907
# Hạng 19888: Uemu039 - 0.0907
# Hạng 19889: UdemeA611 - 0.0907
# Hạng 19890: UNLEASHEDeth - 0.0907
# Hạng 19891: UnrealApe - 0.0907
# Hạng 19892: UN1BRO - 0.0907
# Hạng 19893: UMARSIZAYIBOGAN - 0.0907
# Hạng 19894: DonAplas - 0.0907
# Hạng 19895: UAPsAndNFTs - 0.0907
# Hạng 19896: DonCrypto_ - 0.0907
# Hạng 19897: TzuOfficial - 0.0907
# Hạng 19898: UnfitProdigy - 0.0907
# Hạng 19899: UnsungCrypto - 0.0907
# Hạng 19900: Dmtay79 - 0.0907
# Hạng 19901: DoctapantheR - 0.0907
# Hạng 19902: Vich_33 - 0.0907
# Hạng 19903: VeryEclectic - 0.0907
# Hạng 19904: VeritasDAO - 0.0907
# Hạng 19905: VeraManiac - 0.0907
# Hạng 19906: VatoOnChain - 0.0907
# Hạng 19907: Vaseanfit - 0.0907
# Hạng 19908: Variance_ADA - 0.0907
# Hạng 19909: UpTrend_7 - 0.0907
# Hạng 19910: Van_Whalen - 0.0907
# Hạng 19911: VW_metaX - 0.0907
# Hạng 19912: VV_watch - 0.0907
# Hạng 19913: VT_BNB - 0.0907
# Hạng 19914: VCVCOMEDY - 0.0907
# Hạng 19915: DogeArmy00 - 0.0907
# Hạng 19916: _MobJ - 0.0907
# Hạng 19917: DeFiSurfer808 - 0.0907
# Hạng 19918: bitbrain_crypto - 0.0907
# Hạng 19919: auranism - 0.0907
# Hạng 19920: baadee55 - 0.0907
# Hạng 19921: bOnez_DV - 0.0907
# Hạng 19922: CuttyQ10 - 0.0907
# Hạng 19923: b4kenny - 0.0907
# Hạng 19924: aznablessed - 0.0907
# Hạng 19925: CyberChargeJoe - 0.0907
# Hạng 19926: azeal63 - 0.0907
# Hạng 19927: aymdoteth - 0.0907
# Hạng 19928: aykutzf - 0.0907
# Hạng 19929: avogroovy - 0.0907
# Hạng 19930: avni87744 - 0.0907
# Hạng 19931: CyberTni - 0.0907
# Hạng 19932: avalanche_tr - 0.0907
# Hạng 19933: Cyberbitz - 0.0907
# Hạng 19934: autumnscrypto - 0.0907
# Hạng 19935: bachkhoabnb - 0.0907
# Hạng 19936: Curto_sol - 0.0907
# Hạng 19937: Cursedredd - 0.0907
# Hạng 19938: CullenColors - 0.0907
# Hạng 19939: basedhoodies - 0.0907
# Hạng 19940: bartcheek - 0.0907
# Hạng 19941: CrystalAmelia18 - 0.0907
# Hạng 19942: bart89022099 - 0.0907
# Hạng 19943: Cuentos_ETH - 0.0907
# Hạng 19944: baron_oscarh - 0.0907
# Hạng 19945: baraka_wins - 0.0907
# Hạng 19946: badmanNFTs - 0.0907
# Hạng 19947: CunyboyP - 0.0907
# Hạng 19948: banilizo_nft - 0.0907
# Hạng 19949: CuratedByR - 0.0907
# Hạng 19950: bandobaby_eth - 0.0907
# Hạng 19951: bakedandterpys - 0.0907
# Hạng 19952: baiyu2140 - 0.0907
# Hạng 19953: Cyberwrldeth - 0.0907
# Hạng 19954: aummum_m - 0.0907
# Hạng 19955: apex_intern - 0.0907
# Hạng 19956: atokdase - 0.0907
# Hạng 19957: DAXIAGUA1 - 0.0907
# Hạng 19958: artcruise2910 - 0.0907
# Hạng 19959: artcolllector - 0.0907
# Hạng 19960: artbygarray - 0.0907
# Hạng 19961: art_vandelhey - 0.0907
# Hạng 19962: arloxshot - 0.0907
# Hạng 19963: arkalamh - 0.0907
# Hạng 19964: ark7dev - 0.0907
# Hạng 19965: arizonajeremy - 0.0907
# Hạng 19966: arius_xyz - 0.0907
# Hạng 19967: arikan - 0.0907
# Hạng 19968: ariellexfox - 0.0907
# Hạng 19969: arbiisbored - 0.0907
# Hạng 19970: DFarm_club - 0.0907
# Hạng 19971: aravarc1 - 0.0907
# Hạng 19972: arthurcoins - 0.0907
# Hạng 19973: DAVIDSONCUTE - 0.0907
# Hạng 19974: DAO_O1 - 0.0907
# Hạng 19975: asielcg - 0.0907
# Hạng 19976: atlasXBT - 0.0907
# Hạng 19977: ataraxiaDEFIT - 0.0907
# Hạng 19978: aslanw3b - 0.0907
# Hạng 19979: askemxbt - 0.0907
# Hạng 19980: asimplenoochie - 0.0907
# Hạng 19981: asimfiles - 0.0907
# Hạng 19982: ashishmode - 0.0907
# Hạng 19983: artmichel_eth - 0.0907
# Hạng 19984: ashishknows - 0.0907
# Hạng 19985: D14m0ndHandz - 0.0907
# Hạng 19986: aryaenne - 0.0907
# Hạng 19987: D4LX6IT2 - 0.0907
# Hạng 19988: D4P4ND4 - 0.0907
# Hạng 19989: artoftheinfinte - 0.0907
# Hạng 19990: CryptoxDylan - 0.0907
# Hạng 19991: Cryptowithkhan - 0.0907
# Hạng 19992: Cryptowally2 - 0.0907
# Hạng 19993: Cryptovertexx - 0.0907
# Hạng 19994: bigwil2k3 - 0.0907
# Hạng 19995: bigvucci23 - 0.0907
# Hạng 19996: Crypto_Taco01 - 0.0907
# Hạng 19997: bigroot_eth - 0.0907
# Hạng 19998: Crypto_Tom111 - 0.0907
# Hạng 19999: Crypto_Tony07 - 0.0907
# Hạng 20000: bigcujo_ - 0.0907
# Hạng 20001: Crypto_Tykoon1 - 0.0907
# Hạng 20002: biduoduoduo - 0.0907
# Hạng 20003: bidogold - 0.0907
# Hạng 20004: bibek_raut - 0.0907
# Hạng 20005: Crypto_graxe - 0.0907
# Hạng 20006: Crypto_marcy - 0.0907
# Hạng 20007: bibbu__ - 0.0907
# Hạng 20008: bholdguyyy - 0.0907
# Hạng 20009: bihai996 - 0.0907
# Hạng 20010: bill_ion66 - 0.0907
# Hạng 20011: Crypto_Roamer - 0.0907
# Hạng 20012: Crypto_Heinder - 0.0907
# Hạng 20013: bit_smash - 0.0907
# Hạng 20014: Crypto_Degen809 - 0.0907
# Hạng 20015: biren888 - 0.0907
# Hạng 20016: birdofurdo - 0.0907
# Hạng 20017: bipolarbearr_ - 0.0907
# Hạng 20018: binhhuynh2112 - 0.0907
# Hạng 20019: Crypto_Horseman - 0.0907
# Hạng 20020: billco77 - 0.0907
# Hạng 20021: bingo_eth - 0.0907
# Hạng 20022: binaya_btc - 0.0907
# Hạng 20023: billyzink1 - 0.0907
# Hạng 20024: billyshipp - 0.0907
# Hạng 20025: billxmono - 0.0907
# Hạng 20026: billtheinvestor - 0.0907
# Hạng 20027: bgmshana - 0.0907
# Hạng 20028: betsY_kukU - 0.0907
# Hạng 20029: Cryptocaseman - 0.0907
# Hạng 20030: Cryptophergray - 0.0907
# Hạng 20031: Crypton_on_x - 0.0907
# Hạng 20032: Cryptonic_Bull - 0.0907
# Hạng 20033: Cryptonite94 - 0.0907
# Hạng 20034: beem_1412 - 0.0907
# Hạng 20035: bee_926 - 0.0907
# Hạng 20036: beanstockbets - 0.0907
# Hạng 20037: Cryptorizz_ - 0.0907
# Hạng 20038: Cryptomode_VC - 0.0907
# Hạng 20039: bbsharrkk - 0.0907
# Hạng 20040: bbgmonline - 0.0907
# Hạng 20041: Cryptoscipher - 0.0907
# Hạng 20042: bayc9797 - 0.0907
# Hạng 20043: bax1337 - 0.0907
# Hạng 20044: Cryptotracy27 - 0.0907
# Hạng 20045: beidouxingshequ - 0.0907
# Hạng 20046: Cryptomark247 - 0.0907
# Hạng 20047: berkokid - 0.0907
# Hạng 20048: Cryptoera0 - 0.0907
# Hạng 20049: beorcash - 0.0907
# Hạng 20050: Cryptochunshui - 0.0907
# Hạng 20051: benzobox - 0.0907
# Hạng 20052: benvalhalla - 0.0907
# Hạng 20053: benrbn - 0.0907
# Hạng 20054: benoitded - 0.0907
# Hạng 20055: Cryptoextension - 0.0907
# Hạng 20056: Cryptoloveit - 0.0907
# Hạng 20057: belushidegen - 0.0907
# Hạng 20058: bellew193 - 0.0907
# Hạng 20059: bellacryptoz - 0.0907
# Hạng 20060: belafeid_ - 0.0907
# Hạng 20061: Cryptolissima - 0.0907
# Hạng 20062: bekircagricelik - 0.0907
# Hạng 20063: araojpn - 0.0907
# Hạng 20064: DJohnson_CPA - 0.0907
# Hạng 20065: _Snoww_9 - 0.0907
# Hạng 20066: a821haha - 0.0907
# Hạng 20067: adamsmoot - 0.0907
# Hạng 20068: adamnash - 0.0907
# Hạng 20069: acess_memory - 0.0907
# Hạng 20070: abyssofgambling - 0.0907
# Hạng 20071: ablaz1775 - 0.0907
# Hạng 20072: DariusTabai - 0.0907
# Hạng 20073: abitminations - 0.0907
# Hạng 20074: abh3nav - 0.0907
# Hạng 20075: ab_hogs - 0.0907
# Hạng 20076: aaronpayas - 0.0907
# Hạng 20077: aandooor - 0.0907
# Hạng 20078: aacryptoverse - 0.0907
# Hạng 20079: a_greenberg - 0.0907
# Hạng 20080: a_gh05ty - 0.0907
# Hạng 20081: aPOLARO1D - 0.0907
# Hạng 20082: adamtwiggs - 0.0907
# Hạng 20083: adex4me - 0.0907
# Hạng 20084: Danteoo0 - 0.0907
# Hạng 20085: adrivtv - 0.0907
# Hạng 20086: aesmonty - 0.0907
# Hạng 20087: Daniel_Chang411 - 0.0907
# Hạng 20088: aerfajuice - 0.0907
# Hạng 20089: aeger__ - 0.0907
# Hạng 20090: Daniel_eth2 - 0.0907
# Hạng 20091: aegas_ms - 0.0907
# Hạng 20092: DannyBitcoiner - 0.0907
# Hạng 20093: adeyposi - 0.0907
# Hạng 20094: DannyCrypto85 - 0.0907
# Hạng 20095: adityaxnft - 0.0907
# Hạng 20096: DannyTrieu2 - 0.0907
# Hạng 20097: adityaeth - 0.0907
# Hạng 20098: adiokingeth - 0.0907
# Hạng 20099: adinalini - 0.0907
# Hạng 20100: DarrenT75313849 - 0.0907
# Hạng 20101: Darth_Jader27 - 0.0907
# Hạng 20102: apeuniverse_eth - 0.0907
# Hạng 20103: _yangyou - 0.0907
# Hạng 20104: __yushen - 0.0907
# Hạng 20105: DawnsXu - 0.0907
# Hạng 20106: __solastorm__ - 0.0907
# Hạng 20107: __mrpedro - 0.0907
# Hạng 20108: DbgKinggg - 0.0907
# Hạng 20109: Dbiljonaire - 0.0907
# Hạng 20110: __PR1D3__ - 0.0907
# Hạng 20111: __Aashkan - 0.0907
# Hạng 20112: _Wyb0 - 0.0907
# Hạng 20113: _Tibalt - 0.0907
# Hạng 20114: _TheCaptain___ - 0.0907
# Hạng 20115: _TeeJJ_ - 0.0907
# Hạng 20116: _TOmmy_NFT - 0.0907
# Hạng 20117: DeFiNallyx - 0.0907
# Hạng 20118: _SolGravity - 0.0907
# Hạng 20119: _breannafaye - 0.0907
# Hạng 20120: _demolaa - 0.0907
# Hạng 20121: _derked - 0.0907
# Hạng 20122: _mwc - 0.0907
# Hạng 20123: _topcats - 0.0907
# Hạng 20124: _silto_ - 0.0907
# Hạng 20125: _seanli - 0.0907
# Hạng 20126: _pogai_ - 0.0907
# Hạng 20127: _no_face_888 - 0.0907
# Hạng 20128: _nino_nino__ - 0.0907
# Hạng 20129: _masonmiller - 0.0907
# Hạng 20130: _easyduzit - 0.0907
# Hạng 20131: DaveWaslen - 0.0907
# Hạng 20132: _markfenner - 0.0907
# Hạng 20133: _kokobean - 0.0907
# Hạng 20134: _kishino - 0.0907
# Hạng 20135: _khanhamzah - 0.0907
# Hạng 20136: _kayato - 0.0907
# Hạng 20137: afie33 - 0.0907
# Hạng 20138: agent0n3 - 0.0907
# Hạng 20139: DangerDaveBTC - 0.0907
# Hạng 20140: agocripto - 0.0907
# Hạng 20141: DT_Frosty - 0.0907
# Hạng 20142: andyNFT00 - 0.0907
# Hạng 20143: andrewagnereth - 0.0907
# Hạng 20144: ando_buppan - 0.0907
# Hạng 20145: ametomuchi123 - 0.0907
# Hạng 20146: amazonelope - 0.0907
# Hạng 20147: amanbehumble - 0.0907
# Hạng 20148: amai_zeg - 0.0907
# Hạng 20149: alxfal - 0.0907
# Hạng 20150: alvinfoo - 0.0907
# Hạng 20151: altcoinrookie - 0.0907
# Hạng 20152: D_Dog_NFT - 0.0907
# Hạng 20153: altcoinbear1 - 0.0907
# Hạng 20154: alrawenet - 0.0907
# Hạng 20155: DaCryptoAgency - 0.0907
# Hạng 20156: andyprinz - 0.0907
# Hạng 20157: anes427 - 0.0907
# Hạng 20158: anger_trading - 0.0907
# Hạng 20159: anxiaoqi51 - 0.0907
# Hạng 20160: DMC7778888 - 0.0907
# Hạng 20161: apelicious55 - 0.0907
# Hạng 20162: apeinsteinsol - 0.0907
# Hạng 20163: ape4459 - 0.0907
# Hạng 20164: DNFTETH - 0.0907
# Hạng 20165: aoi_crypto_7 - 0.0907
# Hạng 20166: anser420_ - 0.0907
# Hạng 20167: angpeguero - 0.0907
# Hạng 20168: DOOMbotMask - 0.0907
# Hạng 20169: DOOSINALPHA - 0.0907
# Hạng 20170: anna_tutova - 0.0907
# Hạng 20171: anirudh_chohan - 0.0907
# Hạng 20172: DRiidduu - 0.0907
# Hạng 20173: animixar - 0.0907
# Hạng 20174: DaDaoXiaoLang88 - 0.0907
# Hạng 20175: DaDefiDon - 0.0907
# Hạng 20176: DaNNYi3 - 0.0907
# Hạng 20177: akhkhan1 - 0.0907
# Hạng 20178: alacheng - 0.0907
# Hạng 20179: akshay_pachaar - 0.0907
# Hạng 20180: akpinky923 - 0.0907
# Hạng 20181: akibablade - 0.0907
# Hạng 20182: DamnerLFG - 0.0907
# Hạng 20183: aki_039 - 0.0907
# Hạng 20184: akakiseisai3 - 0.0907
# Hạng 20185: alantks_ - 0.0907
# Hạng 20186: akafish00 - 0.0907
# Hạng 20187: ak_ism49 - 0.0907
# Hạng 20188: ajcwebdev - 0.0907
# Hạng 20189: aimerrys - 0.0907
# Hạng 20190: ahnchrisj - 0.0907
# Hạng 20191: ahgmx01 - 0.0907
# Hạng 20192: alagbe003 - 0.0907
# Hạng 20193: alei198634 - 0.0907
# Hạng 20194: allisonovoxo - 0.0907
# Hạng 20195: alexxshadow - 0.0907
# Hạng 20196: alitiknazoglu - 0.0907
# Hạng 20197: alin_alphapilot - 0.0907
# Hạng 20198: Da_mainZuan - 0.0907
# Hạng 20199: alicememeka - 0.0907
# Hạng 20200: Dabao_X - 0.0907
# Hạng 20201: alexzuo4 - 0.0907
# Hạng 20202: alexsmeelenz - 0.0907
# Hạng 20203: alessatrx - 0.0907
# Hạng 20204: alexocheema - 0.0907
# Hạng 20205: alexmarks3D - 0.0907
# Hạng 20206: alexhughsam - 0.0907
# Hạng 20207: alexgedevani - 0.0907
# Hạng 20208: DaddymadEth - 0.0907
# Hạng 20209: alexSoKrispy - 0.0907
# Hạng 20210: defi_airdrops - 0.0907

# %%
print(results)
# Out:
# {'aixbt_agent': np.float64(81.42860313540118), 'saylor': np.float64(74.3875464871092), 'blknoiz06': np.float64(44.75014912272566), 'cz_binance': np.float64(43.63603887980668), 'jessepollak': np.float64(34.579603586200214), 'notthreadguy': np.float64(33.955366021685734), 'brian_armstrong': np.float64(33.331563587284016), 'CynthiaMLummis': np.float64(32.224885436271286), 'truth_terminal': np.float64(30.603347968145638), 'chooserich': np.float64(30.421238219417642), 'pmarca': np.float64(27.530482584754008), 'LeonidasNFT': np.float64(25.937458677771716), '0xMert_': np.float64(25.737645548276408), 'EleanorTerrett': np.float64(25.536862870218208), '0xzerebro': np.float64(24.177907303301154), 'DegenerateNews': np.float64(24.13321828945698), 'aeyakovenko': np.float64(22.998832407818906), 'LucaNetz': np.float64(22.574304152299987), 'AndyAyrey': np.float64(22.105354022389605), 'MustStopMurad': np.float64(21.86136469161699), 'Dennis_Porter_': np.float64(21.68041820679919), 'shawmakesmagic': np.float64(21.285671356855488), 'beeple': np.float64(20.997754041636572), 'FinancialCmte': np.float64(20.69030688986316), 'frankdegods': np.float64(20.633860190067413), 'justinsuntron': np.float64(20.350166687786597), 'dolos_diary': np.float64(19.11420491103244), 'JSeyff': np.float64(18.952650415122687), 'waleswoosh': np.float64(18.85934353824099), 'leap_xyz': np.float64(18.85196131687469), 'iampaulgrewal': np.float64(18.804259181550822), 'CozomoMedici': np.float64(18.34080707611588), 'EricBalchunas': np.float64(17.75475412989793), 'APompliano': np.float64(17.307652323790304), 'inversebrah': np.float64(17.18920048516351), 'SolJakey': np.float64(16.833255098031575), 'piovincenzo_': np.float64(16.693622993642773), 'AltcoinDailyio': np.float64(16.433892228574), 'natbrunell': np.float64(16.02542997263383), 'AutismCapital': np.float64(15.179393837981626), 'naval': np.float64(15.116635690135855), 'itsafwog': np.float64(15.074973897932786), 'jerallaire': np.float64(14.872773593381321), 'CharlotteFang77': np.float64(14.862153483976057), 'ThinkingUSD': np.float64(14.7589539020696), 'GeezOnApe': np.float64(14.517420265633866), 'based16z': np.float64(14.197010009353537), 'fundstrat': np.float64(13.566228576355368), 'CryptoGarga': np.float64(13.4861018527489), 'BTC_Archive': np.float64(13.38008973697552), 'ZssBecker': np.float64(13.10930942888127), 'weremeow': np.float64(13.103016974615924), 'CathieDWood': np.float64(13.079272249345584), 'JakeGagain': np.float64(12.962650785133176), 'SHL0MS': np.float64(12.796267307739601), 'trentdotsol': np.float64(12.449395328772397), 'ARKInvest': np.float64(12.292460142075615), 'Chilearmy123': np.float64(11.89587188010144), 'RektCoin': np.float64(11.29898606771854), 'USRepMikeFlood': np.float64(11.219787604906687), 'PunterJeff': np.float64(11.193780864733162), 'IOHK_Charles': np.float64(11.172694998379162), 'bryanbrinkman': np.float64(11.047293725364865), 'Jihoz_Axie': np.float64(10.931944768513873), 'farokh': np.float64(10.60071955009369), 'iamDCinvestor': np.float64(10.509264289738933), 'tyler': np.float64(10.453572656168541), 'blockspacepod': np.float64(10.251070507221202), 'Scaramucci': np.float64(10.137400391703247), 'bgarlinghouse': np.float64(10.134798281020311), 'chillguycto': np.float64(9.61179712507752), 'jon_charb': np.float64(9.586409869431751), 'barkmeta': np.float64(9.568743744268083), 'HHorsley': np.float64(9.530459289662435), 'fgthiel': np.float64(9.421835056569778), 'EasyEatsBodega': np.float64(9.353927460810606), 'ICOffenderII': np.float64(9.264173879084085), 'osf_rekt': np.float64(9.2524466272443), 'BlockchainAssn': np.float64(9.179626457111134), 'rasmr_eth': np.float64(9.045108988233817), 'vaneck_us': np.float64(9.026412521807947), 'Groowut': np.float64(8.979937007400414), 'UNFKearth': np.float64(8.920702346937558), 'RaoulGMI': np.float64(8.876727437520099), 'DeeZe': np.float64(8.846305133529741), '0xCygaar': np.float64(8.662084793632731), 'KMSmithDC': np.float64(8.605298552157775), 'RogerDickerman': np.flo ...

# %%
bins = [0, 1, 2, 3, 4, 5, 10, 20, 40, 60, 80, 100]
bin_labels = [f"({bins[i]}-{bins[i+1]}]" for i in range(len(bins) - 1)]

counts = {label: 0 for label in bin_labels}
for username, value in results.items():
    for i in range(len(bins) - 1):
        if bins[i] < value <= bins[i + 1]:
            counts[bin_labels[i]] += 1
            break

for bin_range, count in counts.items():
    print(f"{bin_range}: {count}")
# Out:
# (0-1]: 18353
# (1-2]: 1112
# (2-3]: 329
# (3-4]: 144
# (4-5]: 67
# (5-10]: 135
# (10-20]: 44
# (20-40]: 22
# (40-60]: 2
# (60-80]: 1
# (80-100]: 1

# %%
import matplotlib.pyplot as plt

# Data from the table
counts = {
    "(0-1]": 18353,
    "(1-2]": 1112,
    "(2-3]": 329,
    "(3-4]": 144,
    "(4-5]": 67,
    "(5-10]": 135,
    "(10-20]": 44,
    "(20-40]": 22,
    "(40-60]": 2,
    "(60-80]": 1,
    "(80-100]": 1
}

bins = list(counts.keys())
values = list(counts.values())

plt.figure(figsize=(12, 6))
plt.bar(bins, values, color='skyblue')

for i, value in enumerate(values):
    plt.text(i, value + max(values) * 0.01, str(value), ha='center', fontsize=10)

plt.xlabel('PageRank Score Range', fontsize=12)
plt.ylabel('Number of Users', fontsize=12)
plt.title('Distribution of PageRank Scores', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Save the figure
plt.savefig('score_distribution.png', dpi=300)

# Optional: show the plot
# plt.show()

# %%
import matplotlib.pyplot as plt

bins = list(counts.keys())
values = list(counts.values())

plt.figure(figsize=(12, 6))
plt.bar(bins, values, color='skyblue')

for i, value in enumerate(values):
    plt.text(i, value + max(values) * 0.01, str(value), ha='center', fontsize=10)

plt.xlabel('Score Range', fontsize=12)
plt.ylabel('Number of Nodes', fontsize=12)
plt.title('Exploratory Data Analysis', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.savefig('score_distribution.png')

# %%
line_data = results

# Extracting keys and values for line plot
names = list(line_data.keys())
values = list(line_data.values())

# Plotting the line chart
plt.figure(figsize=(12, 6))
# plt.plot(names, values, marker='o', linestyle='-', color='skyblue')
# plt.scatter(names, values, color='skyblue')
plt.scatter(range(len(values)), values, color='skyblue')

# Adding labels and title
plt.xlabel('User', fontsize=12)
plt.ylabel('Score', fontsize=12)
# plt.title('Line Chart of Data', fontsize=14)
# plt.grid(True, linestyle='--', alpha=0.6)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/c2/4cqh1cmj5yn93my66lj31f6w0000gn/T/ipykernel_15494/2913145678.py:21: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
mapping_follower = {}
for kol in results.keys():
    mapping_follower[kol] = users_col.find_one({"userName": kol})["followersCount"]

# %%
print(mapping_follower)
# Out:
# {'aixbt_agent': 404882, 'saylor': 3997324, 'blknoiz06': 653398, 'cz_binance': 9458130, 'jessepollak': 196773, 'notthreadguy': 263487, 'brian_armstrong': 1468911, 'CynthiaMLummis': 105664, 'truth_terminal': 252086, 'chooserich': 196901, 'pmarca': 1753090, 'LeonidasNFT': 245393, '0xMert_': 183867, 'EleanorTerrett': 169801, '0xzerebro': 114821, 'DegenerateNews': 325288, 'aeyakovenko': 488844, 'LucaNetz': 165816, 'AndyAyrey': 99371, 'MustStopMurad': 649828, 'Dennis_Porter_': 205999, 'shawmakesmagic': 143505, 'beeple': 818782, 'FinancialCmte': 43661, 'frankdegods': 333619, 'justinsuntron': 3726430, 'dolos_diary': 42140, 'JSeyff': 167554, 'waleswoosh': 124906, 'leap_xyz': 76673, 'iampaulgrewal': 83920, 'CozomoMedici': 303717, 'EricBalchunas': 342481, 'APompliano': 1697816, 'inversebrah': 335451, 'SolJakey': 168059, 'piovincenzo_': 83639, 'AltcoinDailyio': 1801100, 'natbrunell': 366345, 'AutismCapital': 666477, 'naval': 2657120, 'itsafwog': 37277, 'jerallaire': 149102, 'CharlotteFang77': 49513, 'ThinkingUSD': 245160, 'GeezOnApe': 26610, 'based16z': 82482, 'fundstrat': 348206, 'CryptoGarga': 112373, 'BTC_Archive': 1626499, 'ZssBecker': 1238325, 'weremeow': 740096, 'CathieDWood': 1770453, 'JakeGagain': 360685, 'SHL0MS': 66627, 'trentdotsol': 6513, 'ARKInvest': 775060, 'Chilearmy123': 27975, 'RektCoin': 34793, 'USRepMikeFlood': 10323, 'PunterJeff': 37355, 'IOHK_Charles': 1022541, 'bryanbrinkman': 77578, 'Jihoz_Axie': 520571, 'farokh': 432550, 'iamDCinvestor': 256129, 'tyler': 1070821, 'blockspacepod': 5186, 'Scaramucci': 1066774, 'bgarlinghouse': 1072906, 'chillguycto': 73112, 'jon_charb': 19778, 'barkmeta': 163353, 'HHorsley': 52647, 'fgthiel': 35388, 'EasyEatsBodega': 107033, 'ICOffenderII': 43488, 'osf_rekt': 200866, 'BlockchainAssn': 37740, 'rasmr_eth': 74540, 'vaneck_us': 93211, 'Groowut': 20268, 'UNFKearth': 92612, 'RaoulGMI': 1139683, 'DeeZe': 271873, '0xCygaar': 119679, 'KMSmithDC': 27479, 'RogerDickerman': 31997, 'keoneHD': 48972, 'boldleonidas': 67934, 'Zagabond': 139545, 'cameron': 740096, 'MaxResnick1': 11960, 'backseats_eth': 16084, 'shiro': 64225, 'RidazLp2': 73460, 'js_horne': 49438, 'GwartyGwart': 29560, 'MINHxDYNASTY': 43262, 'TO': 150346, 'GodsBurnt': 63648, 'IncomeSharks': 607885, 'kris': 354901, 'BitcoinNewsCom': 198940, 'Pizza_Ninjas': 46311, 'RadarHits': 357423, 'rektmando': 161190, 'yellowpantherx': 161448, 'BillyM2k': 2242568, '_RichardTeng': 322187, 'rushimanche': 38401, 'pnutsolana': 62647, 'jyu_eth': 38337, 'gainzy222': 274876, 'hasbulla_main': 454098, 'intangiblecoins': 47985, 'econoar': 174634, 'DavidFBailey': 59725, 'blocknewsdotcom': 34820, 'TheFlowHorse': 256595, 'kikanicolela': 18438, 'himgajria': 87370, 'dankrad': 26330, 'artsch00lreject': 102572, 'wizardofsoho': 133161, 'OhYouBlockhead': 32196, 'solanasteve_': 15824, 'mattmedved': 157880, 'ppmctweets': 55820, 'd_gilz': 32577, 'DSBatten': 43203, 'heyibinance': 335715, 'KookCapitalLLC': 136802, 'lBattleRhino': 55167, 'KevinWSHPod': 44050, 'TiffanyFong_': 323846, 'naiivememe': 217537, 'NateGeraci': 55931, 'EmanAbio': 46698, 'kmoney_69': 149991, 'Tradermayne': 491106, 'Matt_Hougan': 60340, 'dgt10011': 31016, 'BoredApeSolClub': 30505, 'kukulabanze': 26733, 'delta_sauce': 50586, 'MacroCRG': 172897, '0xAneri': 9336, 'rajgokal': 275210, 'CryptoWizardd': 772773, 'digitalartchick': 189199, 'IsaacMiller': 36521, 'cburniske': 317814, 'Vince_Van_Dough': 179441, 'michaelmicasso': 34599, 'RealKatoOG': 62292, 'cryptolution101': 20115, 'dak_daze': 22077, 'seedphrase': 225063, 'ericnode': 57201, 'lerandomart': 5453, '_Shadow36': 71166, 'AlexanderGrieve': 7503, 'BenArmstrongsX': 97273, 'coinbureau': 927973, 'Tyler_Did_It': 44309, 'punk9059': 119112, 'LukeGromen': 315399, 'OneAndOnlyPapii': 99250, 'walletbubbles': 3195, 'theMiningPod': 4496, 'sassal0x': 267843, 'cryptojourneyrs': 114829, 'dotkrueger': 129287, 'DipWheeler': 16152, 'GOPMajorityWhip': 107759, 'sreeramkannan': 38879, 'TrustlessState': 230874, 'SpaceRidersXYZ': 70587, 'gammichan': 33520, 'SatoshiFlipper': 2242 ...
